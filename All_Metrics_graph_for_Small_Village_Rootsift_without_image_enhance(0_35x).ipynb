# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_Small Village_Rootsift_without image enhance(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_Small Village_Rootsift_without image enhance(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_Small Village_Rootsift_without image enhance(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.107000             A
# 1            1  Small Village Dataset  ...  0.127000             A
# 2            2  Small Village Dataset  ...  0.147852             A
# 3            3  Small Village Dataset  ...  0.088000             A
# 4            4  Small Village Dataset  ...  0.078000             A
# ..         ...                    ...  ...       ...           ...
# 74          74  Small Village Dataset  ...  0.058000             A
# 75          75  Small Village Dataset  ...  0.083000             A
# 76          76  Small Village Dataset  ...  0.094000             A
# 77          77  Small Village Dataset  ...  0.008991             A
# 78          78  Small Village Dataset  ...  0.010000             A
#
# [79 rows x 9 columns]

# %%
df1['Parameter'] = "Sift: nfeatures = 1000, nOctaveLayers = 4, contrastThreshold = 0.06, edgeThreshold = 12 "

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# ..         ...  ...                                                ...
# 74          74  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
#
# [79 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.097500             B
# 1            1  Small Village Dataset  ...  0.152500             B
# 2            2  Small Village Dataset  ...  0.137000             B
# 3            3  Small Village Dataset  ...  0.063968             B
# 4            4  Small Village Dataset  ...  0.086000             B
# ..         ...                    ...  ...       ...           ...
# 74          74  Small Village Dataset  ...  0.074500             B
# 75          75  Small Village Dataset  ...  0.094000             B
# 76          76  Small Village Dataset  ...  0.081000             B
# 77          77  Small Village Dataset  ...  0.019000             B
# 78          78  Small Village Dataset  ...  0.009000             B
#
# [79 rows x 9 columns]

# %%
df2['Parameter'] = "Sift: nfeatures = 2000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10"

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 1            1  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 2            2  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 3            3  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 4            4  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# ..         ...  ...                                                ...
# 74          74  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 75          75  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
#
# [79 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.120000             C
# 1            1  Small Village Dataset  ...  0.125000             C
# 2            2  Small Village Dataset  ...  0.135000             C
# 3            3  Small Village Dataset  ...  0.079000             C
# 4            4  Small Village Dataset  ...  0.094000             C
# ..         ...                    ...  ...       ...           ...
# 74          74  Small Village Dataset  ...  0.061000             C
# 75          75  Small Village Dataset  ...  0.087000             C
# 76          76  Small Village Dataset  ...  0.093906             C
# 77          77  Small Village Dataset  ...  0.009000             C
# 78          78  Small Village Dataset  ...  0.007000             C
#
# [79 rows x 9 columns]

# %%
df3['Parameter'] = "Sift: nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 8"

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# ..         ...  ...                                                ...
# 74          74  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
#
# [79 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# ..         ...  ...                                                ...
# 74          74  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
#
# [237 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for ROOTSIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for ROOTSIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for ROOTSIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for ROOTSIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for ROOTSIFT for different parameter combinations')
