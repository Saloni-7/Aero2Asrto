# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_MAP_Surf+Sift_without image enhancement(0.5x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_MAP_Surf+Sift_without image enhancement(0.5x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_MAP_Surf+Sift_without image enhancement(0.5x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.154088             A
# 1            1  MAP Dataset  ...  0.152812             A
# 2            2  MAP Dataset  ...  0.138332             A
# 3            3  MAP Dataset  ...  0.118939             A
# 4            4  MAP Dataset  ...  0.005156             A
# ..         ...          ...  ...       ...           ...
# 74          74  MAP Dataset  ...  0.157455             A
# 75          75  MAP Dataset  ...  0.169556             A
# 76          76  MAP Dataset  ...  0.184325             A
# 77          77  MAP Dataset  ...  0.194542             A
# 78          78  MAP Dataset  ...  0.214727             A
#
# [79 rows x 9 columns]

# %%
df1['Parameter'] = "Surf:hessianThreshold =40, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 74          74  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 75          75  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 76          76  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 77          77  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 78          78  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
#
# [79 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.157978             B
# 1            1  MAP Dataset  ...  0.158900             B
# 2            2  MAP Dataset  ...  0.145103             B
# 3            3  MAP Dataset  ...  0.113259             B
# 4            4  MAP Dataset  ...  0.005638             B
# ..         ...          ...  ...       ...           ...
# 74          74  MAP Dataset  ...  0.158536             B
# 75          75  MAP Dataset  ...  0.168548             B
# 76          76  MAP Dataset  ...  0.188264             B
# 77          77  MAP Dataset  ...  0.206850             B
# 78          78  MAP Dataset  ...  0.211914             B
#
# [79 rows x 9 columns]

# %%
df2['Parameter'] = "Surf:hessianThreshold =60, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 74          74  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 75          75  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 76          76  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 77          77  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 78          78  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
#
# [79 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.179173             C
# 1            1  MAP Dataset  ...  0.179495             C
# 2            2  MAP Dataset  ...  0.151940             C
# 3            3  MAP Dataset  ...  0.179338             C
# 4            4  MAP Dataset  ...  0.170288             C
# 5            5  MAP Dataset  ...  0.152891             C
# 6            6  MAP Dataset  ...  0.154364             C
# 7            7  MAP Dataset  ...  0.140554             C
# 8            8  MAP Dataset  ...  0.128314             C
# 9            9  MAP Dataset  ...  0.112214             C
# 10          10  MAP Dataset  ...  0.003113             C
# 11          11  MAP Dataset  ...  0.337596             C
# 12          12  MAP Dataset  ...  0.171627             C
# 13          13  MAP Dataset  ...  0.181889             C
# 14          14  MAP Dataset  ...  0.202159             C
# 15          15  MAP Dataset  ...  0.207902             C
# 16          16  MAP Dataset  ...  0.207378             C
# 17          17  MAP Dataset  ...  0.195440             C
# 18          18  MAP Dataset  ...  0.146379             C
# 19          19  MAP Dataset  ...  0.170148             C
# 20          20  MAP Dataset  ...  0.118809             C
# 21          21  MAP Dataset  ...  0.012419             C
# 22          22  MAP Dataset  ...  0.433555             C
# 23          23  MAP Dataset  ...  0.227899             C
# 24          24  MAP Dataset  ...  0.180216             C
# 25          25  MAP Dataset  ...  0.174993             C
# 26          26  MAP Dataset  ...  0.191079             C
# 27          27  MAP Dataset  ...  0.164032             C
# 28          28  MAP Dataset  ...  0.031549             C
# 29          29  MAP Dataset  ...  0.292859             C
# 30          30  MAP Dataset  ...  0.185389             C
# 31          31  MAP Dataset  ...  0.170514             C
# 32          32  MAP Dataset  ...  0.139087             C
# 33          33  MAP Dataset  ...  0.175280             C
# 34          34  MAP Dataset  ...  0.411380             C
# 35          35  MAP Dataset  ...  0.005353             C
# 36          36  MAP Dataset  ...  0.133170             C
# 37          37  MAP Dataset  ...  0.137934             C
# 38          38  MAP Dataset  ...  0.156079             C
# 39          39  MAP Dataset  ...  0.143084             C
# 40          40  MAP Dataset  ...  0.152939             C
# 41          41  MAP Dataset  ...  0.162224             C
# 42          42  MAP Dataset  ...  0.170262             C
# 43          43  MAP Dataset  ...  0.158977             C
# 44          44  MAP Dataset  ...  0.160125             C
# 45          45  MAP Dataset  ...  0.145178             C
# 46          46  MAP Dataset  ...  0.146668             C
# 47          47  MAP Dataset  ...  0.115441             C
# 48          48  MAP Dataset  ...  0.122052             C
# 49          49  MAP Dataset  ...  0.125832             C
# 50          50  MAP Dataset  ...  0.112250             C
# 51          51  MAP Dataset  ...  0.112904             C
# 52          52  MAP Dataset  ...  0.126746             C
# 53          53  MAP Dataset  ...  0.126931             C
# 54          54  MAP Dataset  ...  0.208126             C
# 55          55  MAP Dataset  ...  0.008415             C
# 56          56  MAP Dataset  ...  0.089377             C
# 57          57  MAP Dataset  ...  0.112693             C
# 58          58  MAP Dataset  ...  0.085903             C
#
# [59 rows x 9 columns]

# %%
df3['Parameter'] = "Surf:hessianThreshold =80, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 5            5  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 6            6  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 7            7  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 8            8  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 9            9  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 10          10  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 11          11  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 12          12  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 13          13  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 14          14  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 15          15  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 16          16  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 17          17  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 18          18  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 19          19  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 20          20  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 21          21  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 22          22  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 23          23  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 24          24  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 25          25  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 26          26  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 27          27  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 28          28  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 29          29  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 30          30  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 31          31  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 32          32  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 33          33  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 34          34  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 35          35  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 36          36  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 37          37  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 38          38  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 39          39  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 40          40  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 41          41  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 42          42  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 43          43  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 44          44  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 45          45  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 46          46  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 47          47  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 48          48  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 49          49  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 50          50  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 51          51  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 52          52  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 53          53  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 54          54  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 55          55  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 56          56  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 57          57  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 58          58  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
#
# [59 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 54          54  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 55          55  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 56          56  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 57          57  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 58          58  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
#
# [217 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF+SIFT for different parameter combinations')
