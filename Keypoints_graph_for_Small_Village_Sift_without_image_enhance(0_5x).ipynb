# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Sift_without image enhance(0.5x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Small Village_Sift_without image enhance(0.5x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Sift_without image enhance(0.5x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...                 SIFT             A
# 1            1  Small Village Dataset  ...                 SIFT             A
# 2            2  Small Village Dataset  ...                 SIFT             A
# 3            3  Small Village Dataset  ...                 SIFT             A
# 4            4  Small Village Dataset  ...                 SIFT             A
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...                 SIFT             A
# 76          76  Small Village Dataset  ...                 SIFT             A
# 77          77  Small Village Dataset  ...                 SIFT             A
# 78          78  Small Village Dataset  ...                 SIFT             A
# 79          79  Small Village Dataset  ...                 SIFT             A
#
# [80 rows x 5 columns]

# %%
df1['Parameter'] = "nfeatures = 1000, nOctaveLayers = 4, contrastThreshold = 0.06, edgeThreshold = 12"

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# ..         ...  ...                                                ...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 79          79  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
#
# [80 rows x 6 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...                 SIFT             B
# 1            1  Small Village Dataset  ...                 SIFT             B
# 2            2  Small Village Dataset  ...                 SIFT             B
# 3            3  Small Village Dataset  ...                 SIFT             B
# 4            4  Small Village Dataset  ...                 SIFT             B
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...                 SIFT             B
# 76          76  Small Village Dataset  ...                 SIFT             B
# 77          77  Small Village Dataset  ...                 SIFT             B
# 78          78  Small Village Dataset  ...                 SIFT             B
# 79          79  Small Village Dataset  ...                 SIFT             B
#
# [80 rows x 5 columns]

# %%
df2['Parameter'] = "nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10"

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 79          79  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [80 rows x 6 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...                 SIFT             C
# 1            1  Small Village Dataset  ...                 SIFT             C
# 2            2  Small Village Dataset  ...                 SIFT             C
# 3            3  Small Village Dataset  ...                 SIFT             C
# 4            4  Small Village Dataset  ...                 SIFT             C
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...                 SIFT             C
# 76          76  Small Village Dataset  ...                 SIFT             C
# 77          77  Small Village Dataset  ...                 SIFT             C
# 78          78  Small Village Dataset  ...                 SIFT             C
# 79          79  Small Village Dataset  ...                 SIFT             C
#
# [80 rows x 5 columns]

# %%
df3['Parameter'] = "nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 8"

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 79          79  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [80 rows x 6 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 4, contrastT...
# ..         ...  ...                                                ...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 79          79  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations')
