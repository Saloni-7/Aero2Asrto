# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_ORB_without image enhancement(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_ORB_without image enhancement(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_ORB_without image enhancement(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...                  ORB             A
# 1            1  MAP Dataset  ...                  ORB             A
# 2            2  MAP Dataset  ...                  ORB             A
# 3            3  MAP Dataset  ...                  ORB             A
# 4            4  MAP Dataset  ...                  ORB             A
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...                  ORB             A
# 96          96  MAP Dataset  ...                  ORB             A
# 97          97  MAP Dataset  ...                  ORB             A
# 98          98  MAP Dataset  ...                  ORB             A
# 99          99  MAP Dataset  ...                  ORB             A
#
# [100 rows x 5 columns]

# %%
df1['Parameter'] = " nfeatures= 40000"

# %%
df1
# Out:
#     Unnamed: 0      Dataset  ...  ParameterName          Parameter
# 0            0  MAP Dataset  ...              A   nfeatures= 40000
# 1            1  MAP Dataset  ...              A   nfeatures= 40000
# 2            2  MAP Dataset  ...              A   nfeatures= 40000
# 3            3  MAP Dataset  ...              A   nfeatures= 40000
# 4            4  MAP Dataset  ...              A   nfeatures= 40000
# ..         ...          ...  ...            ...                ...
# 95          95  MAP Dataset  ...              A   nfeatures= 40000
# 96          96  MAP Dataset  ...              A   nfeatures= 40000
# 97          97  MAP Dataset  ...              A   nfeatures= 40000
# 98          98  MAP Dataset  ...              A   nfeatures= 40000
# 99          99  MAP Dataset  ...              A   nfeatures= 40000
#
# [100 rows x 6 columns]

# %%
df2
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...                  ORB             B
# 1            1  MAP Dataset  ...                  ORB             B
# 2            2  MAP Dataset  ...                  ORB             B
# 3            3  MAP Dataset  ...                  ORB             B
# 4            4  MAP Dataset  ...                  ORB             B
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...                  ORB             B
# 96          96  MAP Dataset  ...                  ORB             B
# 97          97  MAP Dataset  ...                  ORB             B
# 98          98  MAP Dataset  ...                  ORB             B
# 99          99  MAP Dataset  ...                  ORB             B
#
# [100 rows x 5 columns]

# %%
df2['Parameter'] = "nfeatures= 60000"

# %%
df2
# Out:
#     Unnamed: 0      Dataset  ...  ParameterName         Parameter
# 0            0  MAP Dataset  ...              B  nfeatures= 60000
# 1            1  MAP Dataset  ...              B  nfeatures= 60000
# 2            2  MAP Dataset  ...              B  nfeatures= 60000
# 3            3  MAP Dataset  ...              B  nfeatures= 60000
# 4            4  MAP Dataset  ...              B  nfeatures= 60000
# ..         ...          ...  ...            ...               ...
# 95          95  MAP Dataset  ...              B  nfeatures= 60000
# 96          96  MAP Dataset  ...              B  nfeatures= 60000
# 97          97  MAP Dataset  ...              B  nfeatures= 60000
# 98          98  MAP Dataset  ...              B  nfeatures= 60000
# 99          99  MAP Dataset  ...              B  nfeatures= 60000
#
# [100 rows x 6 columns]

# %%
df3
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...                  ORB             C
# 1            1  MAP Dataset  ...                  ORB             C
# 2            2  MAP Dataset  ...                  ORB             C
# 3            3  MAP Dataset  ...                  ORB             C
# 4            4  MAP Dataset  ...                  ORB             C
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...                  ORB             C
# 96          96  MAP Dataset  ...                  ORB             C
# 97          97  MAP Dataset  ...                  ORB             C
# 98          98  MAP Dataset  ...                  ORB             C
# 99          99  MAP Dataset  ...                  ORB             C
#
# [100 rows x 5 columns]

# %%
df3['Parameter'] = "nfeatures= 80000"

# %%
df3
# Out:
#     Unnamed: 0      Dataset  ...  ParameterName         Parameter
# 0            0  MAP Dataset  ...              C  nfeatures= 80000
# 1            1  MAP Dataset  ...              C  nfeatures= 80000
# 2            2  MAP Dataset  ...              C  nfeatures= 80000
# 3            3  MAP Dataset  ...              C  nfeatures= 80000
# 4            4  MAP Dataset  ...              C  nfeatures= 80000
# ..         ...          ...  ...            ...               ...
# 95          95  MAP Dataset  ...              C  nfeatures= 80000
# 96          96  MAP Dataset  ...              C  nfeatures= 80000
# 97          97  MAP Dataset  ...              C  nfeatures= 80000
# 98          98  MAP Dataset  ...              C  nfeatures= 80000
# 99          99  MAP Dataset  ...              C  nfeatures= 80000
#
# [100 rows x 6 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0      Dataset  ...  ParameterName          Parameter
# 0            0  MAP Dataset  ...              A   nfeatures= 40000
# 1            1  MAP Dataset  ...              A   nfeatures= 40000
# 2            2  MAP Dataset  ...              A   nfeatures= 40000
# 3            3  MAP Dataset  ...              A   nfeatures= 40000
# 4            4  MAP Dataset  ...              A   nfeatures= 40000
# ..         ...          ...  ...            ...                ...
# 95          95  MAP Dataset  ...              C   nfeatures= 80000
# 96          96  MAP Dataset  ...              C   nfeatures= 80000
# 97          97  MAP Dataset  ...              C   nfeatures= 80000
# 98          98  MAP Dataset  ...              C   nfeatures= 80000
# 99          99  MAP Dataset  ...              C   nfeatures= 80000
#
# [300 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for ORB for different parameter combinations')
