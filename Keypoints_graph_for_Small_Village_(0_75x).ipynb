# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_5_Small Village Dataset_changed threshold_(0.75x)_5.csv')

# %%
df1['ParameterName'] = "A"

# %%
X=pd.read_csv('/content/Num_Kypoints_3_Small Village Datasets_changed parameter_(0.75x).csv')

# %%
Y=pd.read_csv('/content/Num_Kypoints_2_Small Village Dataset_fast, agast_changed parameters_(0.75x).csv')

# %%
df2=pd.concat([X,Y])

# %%
df2['ParameterName'] = "B"

# %%
df1
# Out:
#      Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0             0  Small Village Dataset  ...            FAST+SIFT             A
# 1             1  Small Village Dataset  ...            FAST+SIFT             A
# 2             2  Small Village Dataset  ...            FAST+SIFT             A
# 3             3  Small Village Dataset  ...            FAST+SIFT             A
# 4             4  Small Village Dataset  ...            FAST+SIFT             A
# ..          ...                    ...  ...                  ...           ...
# 595         595  Small Village Dataset  ...          BRISK+FREAK             A
# 596         596  Small Village Dataset  ...          BRISK+FREAK             A
# 597         597  Small Village Dataset  ...          BRISK+FREAK             A
# 598         598  Small Village Dataset  ...          BRISK+FREAK             A
# 599         599  Small Village Dataset  ...          BRISK+FREAK             A
#
# [600 rows x 5 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "AGAST: Threshold = 80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 120         120  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 121         121  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 122         122  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 123         123  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 124         124  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# ..          ...  ...                                                ...
# 235         235  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 236         236  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 237         237  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 238         238  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 239         239  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
#
# [120 rows x 6 columns]

# %%
df2
# Out:
#      Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0             0  Small Village Dataset  ...          BRISK+FREAK             B
# 1             1  Small Village Dataset  ...          BRISK+FREAK             B
# 2             2  Small Village Dataset  ...          BRISK+FREAK             B
# 3             3  Small Village Dataset  ...          BRISK+FREAK             B
# 4             4  Small Village Dataset  ...          BRISK+FREAK             B
# ..          ...                    ...  ...                  ...           ...
# 235         235  Small Village Dataset  ...           AGAST+SIFT             B
# 236         236  Small Village Dataset  ...           AGAST+SIFT             B
# 237         237  Small Village Dataset  ...           AGAST+SIFT             B
# 238         238  Small Village Dataset  ...           AGAST+SIFT             B
# 239         239  Small Village Dataset  ...           AGAST+SIFT             B
#
# [600 rows x 5 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "Agast: Threshold= 60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 120         120  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 121         121  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 122         122  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 123         123  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 124         124  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# ..          ...  ...                                                ...
# 235         235  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 236         236  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 237         237  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 238         238  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 239         239  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
#
# [120 rows x 6 columns]

# %%
ALL_AGAST=pd.concat([AGAST_SIFT, AGAST_SIFT1])

# %%
ALL_AGAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 120         120  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 121         121  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 122         122  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 123         123  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 124         124  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# ..          ...  ...                                                ...
# 235         235  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 236         236  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 237         237  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 238         238  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 239         239  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=ALL_AGAST, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF+SIFT")]

# %%
SURF['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 357         357  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 358         358  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 359         359  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [120 rows x 6 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 357         357  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 358         358  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 359         359  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [120 rows x 6 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1])

# %%
ALL_SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 357         357  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 358         358  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 359         359  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "BRISK: Threshold=80, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0  ...                       Parameter
# 480         480  ...  BRISK: Threshold=80, Octaves=6
# 481         481  ...  BRISK: Threshold=80, Octaves=6
# 482         482  ...  BRISK: Threshold=80, Octaves=6
# 483         483  ...  BRISK: Threshold=80, Octaves=6
# 484         484  ...  BRISK: Threshold=80, Octaves=6
# ..          ...  ...                             ...
# 595         595  ...  BRISK: Threshold=80, Octaves=6
# 596         596  ...  BRISK: Threshold=80, Octaves=6
# 597         597  ...  BRISK: Threshold=80, Octaves=6
# 598         598  ...  BRISK: Threshold=80, Octaves=6
# 599         599  ...  BRISK: Threshold=80, Octaves=6
#
# [120 rows x 6 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "BRISK: Threshl=60, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0  ...                     Parameter
# 0             0  ...  BRISK: Threshl=60, Octaves=6
# 1             1  ...  BRISK: Threshl=60, Octaves=6
# 2             2  ...  BRISK: Threshl=60, Octaves=6
# 3             3  ...  BRISK: Threshl=60, Octaves=6
# 4             4  ...  BRISK: Threshl=60, Octaves=6
# ..          ...  ...                           ...
# 115         115  ...  BRISK: Threshl=60, Octaves=6
# 116         116  ...  BRISK: Threshl=60, Octaves=6
# 117         117  ...  BRISK: Threshl=60, Octaves=6
# 118         118  ...  BRISK: Threshl=60, Octaves=6
# 119         119  ...  BRISK: Threshl=60, Octaves=6
#
# [120 rows x 6 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0  ...                       Parameter
# 480         480  ...  BRISK: Threshold=80, Octaves=6
# 481         481  ...  BRISK: Threshold=80, Octaves=6
# 482         482  ...  BRISK: Threshold=80, Octaves=6
# 483         483  ...  BRISK: Threshold=80, Octaves=6
# 484         484  ...  BRISK: Threshold=80, Octaves=6
# ..          ...  ...                             ...
# 115         115  ...    BRISK: Threshl=60, Octaves=6
# 116         116  ...    BRISK: Threshl=60, Octaves=6
# 117         117  ...    BRISK: Threshl=60, Octaves=6
# 118         118  ...    BRISK: Threshl=60, Octaves=6
# 119         119  ...    BRISK: Threshl=60, Octaves=6
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 475         475  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 476         476  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 477         477  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 478         478  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 479         479  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 120         120  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 121         121  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 122         122  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 123         123  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 124         124  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 235         235  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 238         238  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 239         239  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 235         235  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 238         238  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 239         239  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "FAST: Threshold=70; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 119         119  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
#
# [120 rows x 6 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "FAST: Threshold=70; SIFT: nfeatures = 500, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# ..          ...  ...                                                ...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 119         119  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
#
# [120 rows x 6 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1])

# %%
ALL_FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 119         119  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations')
