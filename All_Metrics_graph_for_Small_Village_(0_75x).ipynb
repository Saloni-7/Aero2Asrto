# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_5_small village_changed threshold_(0.75x)_5.csv')

# %%
df1['ParameterName'] = "A"

# %%
X=pd.read_csv('/content/All_metrics_3_small village_changed parameter_(0.75x).csv')

# %%
Y=pd.read_csv('/content/All_metrics_2_small village_fast, agast_changed parameters_(0.75x).csv')

# %%
df2=pd.concat([X,Y])

# %%
df2['ParameterName'] = "B"

# %%
df1
# Out:
#      Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0             0  Small Village Dataset  ...  0.079307             A
# 1             1  Small Village Dataset  ...  0.107078             A
# 2             2  Small Village Dataset  ...  0.103463             A
# 3             3  Small Village Dataset  ...  0.115742             A
# 4             4  Small Village Dataset  ...  0.049197             A
# ..          ...                    ...  ...       ...           ...
# 590         590  Small Village Dataset  ...  0.004305             A
# 591         591  Small Village Dataset  ...  0.018859             A
# 592         592  Small Village Dataset  ...  0.066218             A
# 593         593  Small Village Dataset  ...  0.094033             A
# 594         594  Small Village Dataset  ...  0.000829             A
#
# [595 rows x 9 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "AGAST: Threshold = 80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 120         120  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 121         121  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 122         122  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 123         123  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# ..          ...  ...                                                ...
# 233         233  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 234         234  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 235         235  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 236         236  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 237         237  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
#
# [119 rows x 10 columns]

# %%
df2
# Out:
#      Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0             0  Small Village Dataset  ...  0.031000             B
# 1             1  Small Village Dataset  ...  0.044000             B
# 2             2  Small Village Dataset  ...  0.035000             B
# 3             3  Small Village Dataset  ...  0.046000             B
# 4             4  Small Village Dataset  ...  0.040959             B
# ..          ...                    ...  ...       ...           ...
# 233         233  Small Village Dataset  ...  0.081561             B
# 234         234  Small Village Dataset  ...  0.191164             B
# 235         235  Small Village Dataset  ...  0.280687             B
# 236         236  Small Village Dataset  ...  0.506765             B
# 237         237  Small Village Dataset  ...  0.001103             B
#
# [595 rows x 9 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "Agast: Threshold= 60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 120         120  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 121         121  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 122         122  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 123         123  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# ..          ...  ...                                                ...
# 233         233  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 234         234  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 235         235  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 236         236  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 237         237  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
#
# [119 rows x 10 columns]

# %%
df=pd.concat([AGAST_SIFT, AGAST_SIFT1])

# %%
df
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 120         120  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 121         121  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 122         122  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 123         123  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# ..          ...  ...                                                ...
# 233         233  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 234         234  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 235         235  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 236         236  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
# 237         237  ...  Agast: Threshold= 60; SIFT: nfeatures = 1000, ...
#
# [238 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matchesfor AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matchesfor AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF+SIFT")]

# %%
SURF['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 352         352  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 353         353  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 354         354  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [119 rows x 10 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 352         352  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 353         353  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 354         354  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [119 rows x 10 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1])

# %%
ALL_SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 352         352  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 353         353  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 354         354  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 355         355  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 356         356  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [238 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "BRISK: Threshold=80, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0  ...                       Parameter
# 476         476  ...  BRISK: Threshold=80, Octaves=6
# 477         477  ...  BRISK: Threshold=80, Octaves=6
# 478         478  ...  BRISK: Threshold=80, Octaves=6
# 479         479  ...  BRISK: Threshold=80, Octaves=6
# 480         480  ...  BRISK: Threshold=80, Octaves=6
# ..          ...  ...                             ...
# 590         590  ...  BRISK: Threshold=80, Octaves=6
# 591         591  ...  BRISK: Threshold=80, Octaves=6
# 592         592  ...  BRISK: Threshold=80, Octaves=6
# 593         593  ...  BRISK: Threshold=80, Octaves=6
# 594         594  ...  BRISK: Threshold=80, Octaves=6
#
# [119 rows x 10 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "BRISK: Threshl=60, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0  ...                     Parameter
# 119         119  ...  BRISK: Threshl=60, Octaves=6
# 120         120  ...  BRISK: Threshl=60, Octaves=6
# 121         121  ...  BRISK: Threshl=60, Octaves=6
# 122         122  ...  BRISK: Threshl=60, Octaves=6
# 123         123  ...  BRISK: Threshl=60, Octaves=6
# ..          ...  ...                           ...
# 233         233  ...  BRISK: Threshl=60, Octaves=6
# 234         234  ...  BRISK: Threshl=60, Octaves=6
# 235         235  ...  BRISK: Threshl=60, Octaves=6
# 236         236  ...  BRISK: Threshl=60, Octaves=6
# 237         237  ...  BRISK: Threshl=60, Octaves=6
#
# [119 rows x 10 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0  ...                       Parameter
# 476         476  ...  BRISK: Threshold=80, Octaves=6
# 477         477  ...  BRISK: Threshold=80, Octaves=6
# 478         478  ...  BRISK: Threshold=80, Octaves=6
# 479         479  ...  BRISK: Threshold=80, Octaves=6
# 480         480  ...  BRISK: Threshold=80, Octaves=6
# ..          ...  ...                             ...
# 233         233  ...    BRISK: Threshl=60, Octaves=6
# 234         234  ...    BRISK: Threshl=60, Octaves=6
# 235         235  ...    BRISK: Threshl=60, Octaves=6
# 236         236  ...    BRISK: Threshl=60, Octaves=6
# 237         237  ...    BRISK: Threshl=60, Octaves=6
#
# [238 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 357         357  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 358         358  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 359         359  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 360         360  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 471         471  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 472         472  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 473         473  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 474         474  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 475         475  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [119 rows x 10 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 1             1  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 2             2  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 3             3  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 4             4  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 114         114  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 115         115  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 116         116  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 117         117  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 118         118  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [119 rows x 10 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 357         357  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 358         358  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 359         359  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 360         360  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 114         114  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 115         115  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 116         116  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 117         117  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 118         118  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [238 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "FAST: Threshold=70; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 114         114  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
#
# [119 rows x 10 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "FAST: Threshold=70; SIFT: nfeatures = 500, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# ..          ...  ...                                                ...
# 114         114  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
#
# [119 rows x 10 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1])

# %%
ALL_FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 1             1  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 2             2  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 3             3  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# 4             4  ...  FAST: Threshold=70; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 114         114  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 115         115  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 116         116  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 117         117  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
# 118         118  ...  FAST: Threshold=70; SIFT: nfeatures = 500, con...
#
# [238 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for FAST+SIFT for different parameter combinations')
