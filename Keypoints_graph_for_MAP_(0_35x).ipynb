# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_5_MAP Dataset_Changed_Parameters_(0.35x)_4.csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_5_MAP Dataset_Freak,Sift,Surf,Agast,Fast(changed parameter)_120 image(0.35x).csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_5_MAP Dataset_changed parameter_(0.35x)_3.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           AGAST+SIFT             A
# 1             1  MAP Dataset  ...           AGAST+SIFT             A
# 2             2  MAP Dataset  ...           AGAST+SIFT             A
# 3             3  MAP Dataset  ...           AGAST+SIFT             A
# 4             4  MAP Dataset  ...           AGAST+SIFT             A
# ..          ...          ...  ...                  ...           ...
# 595         595  MAP Dataset  ...                 SURF             A
# 596         596  MAP Dataset  ...                 SURF             A
# 597         597  MAP Dataset  ...                 SURF             A
# 598         598  MAP Dataset  ...                 SURF             A
# 599         599  MAP Dataset  ...                 SURF             A
#
# [600 rows x 5 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "Agast Threshold= 60 "

# %%
AGAST_SIFT
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName             Parameter
# 0             0  MAP Dataset  ...              A  Agast Threshold= 60
# 1             1  MAP Dataset  ...              A  Agast Threshold= 60
# 2             2  MAP Dataset  ...              A  Agast Threshold= 60
# 3             3  MAP Dataset  ...              A  Agast Threshold= 60
# 4             4  MAP Dataset  ...              A  Agast Threshold= 60
# ..          ...          ...  ...            ...                   ...
# 115         115  MAP Dataset  ...              A  Agast Threshold= 60
# 116         116  MAP Dataset  ...              A  Agast Threshold= 60
# 117         117  MAP Dataset  ...              A  Agast Threshold= 60
# 118         118  MAP Dataset  ...              A  Agast Threshold= 60
# 119         119  MAP Dataset  ...              A  Agast Threshold= 60
#
# [120 rows x 6 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           AGAST+SIFT             B
# 1             1  MAP Dataset  ...           AGAST+SIFT             B
# 2             2  MAP Dataset  ...           AGAST+SIFT             B
# 3             3  MAP Dataset  ...           AGAST+SIFT             B
# 4             4  MAP Dataset  ...           AGAST+SIFT             B
# ..          ...          ...  ...                  ...           ...
# 595         595  MAP Dataset  ...                 SURF             B
# 596         596  MAP Dataset  ...                 SURF             B
# 597         597  MAP Dataset  ...                 SURF             B
# 598         598  MAP Dataset  ...                 SURF             B
# 599         599  MAP Dataset  ...                 SURF             B
#
# [600 rows x 5 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "Agast Threshold= 40"

# %%
AGAST_SIFT1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName            Parameter
# 0             0  MAP Dataset  ...              B  Agast Threshold= 40
# 1             1  MAP Dataset  ...              B  Agast Threshold= 40
# 2             2  MAP Dataset  ...              B  Agast Threshold= 40
# 3             3  MAP Dataset  ...              B  Agast Threshold= 40
# 4             4  MAP Dataset  ...              B  Agast Threshold= 40
# ..          ...          ...  ...            ...                  ...
# 115         115  MAP Dataset  ...              B  Agast Threshold= 40
# 116         116  MAP Dataset  ...              B  Agast Threshold= 40
# 117         117  MAP Dataset  ...              B  Agast Threshold= 40
# 118         118  MAP Dataset  ...              B  Agast Threshold= 40
# 119         119  MAP Dataset  ...              B  Agast Threshold= 40
#
# [120 rows x 6 columns]

# %%
df3
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           AGAST+SIFT             C
# 1             1  MAP Dataset  ...           AGAST+SIFT             C
# 2             2  MAP Dataset  ...           AGAST+SIFT             C
# 3             3  MAP Dataset  ...           AGAST+SIFT             C
# 4             4  MAP Dataset  ...           AGAST+SIFT             C
# ..          ...          ...  ...                  ...           ...
# 595         595  MAP Dataset  ...                 SURF             C
# 596         596  MAP Dataset  ...                 SURF             C
# 597         597  MAP Dataset  ...                 SURF             C
# 598         598  MAP Dataset  ...                 SURF             C
# 599         599  MAP Dataset  ...                 SURF             C
#
# [600 rows x 5 columns]

# %%
AGAST_SIFT2=df3.loc[(df3['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT2['Parameter'] = "Agast Threshold= 60"

# %%
AGAST_SIFT2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName            Parameter
# 0             0  MAP Dataset  ...              C  Agast Threshold= 60
# 1             1  MAP Dataset  ...              C  Agast Threshold= 60
# 2             2  MAP Dataset  ...              C  Agast Threshold= 60
# 3             3  MAP Dataset  ...              C  Agast Threshold= 60
# 4             4  MAP Dataset  ...              C  Agast Threshold= 60
# ..          ...          ...  ...            ...                  ...
# 115         115  MAP Dataset  ...              C  Agast Threshold= 60
# 116         116  MAP Dataset  ...              C  Agast Threshold= 60
# 117         117  MAP Dataset  ...              C  Agast Threshold= 60
# 118         118  MAP Dataset  ...              C  Agast Threshold= 60
# 119         119  MAP Dataset  ...              C  Agast Threshold= 60
#
# [120 rows x 6 columns]

# %%
df=pd.concat([AGAST_SIFT, AGAST_SIFT1, AGAST_SIFT2])

# %%
df
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName             Parameter
# 0             0  MAP Dataset  ...              A  Agast Threshold= 60
# 1             1  MAP Dataset  ...              A  Agast Threshold= 60
# 2             2  MAP Dataset  ...              A  Agast Threshold= 60
# 3             3  MAP Dataset  ...              A  Agast Threshold= 60
# 4             4  MAP Dataset  ...              A  Agast Threshold= 60
# ..          ...          ...  ...            ...                   ...
# 115         115  MAP Dataset  ...              C   Agast Threshold= 60
# 116         116  MAP Dataset  ...              C   Agast Threshold= 60
# 117         117  MAP Dataset  ...              C   Agast Threshold= 60
# 118         118  MAP Dataset  ...              C   Agast Threshold= 60
# 119         119  MAP Dataset  ...              C   Agast Threshold= 60
#
# [360 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF")]

# %%
SURF['Parameter'] = "hessianThreshold = 60"

# %%
SURF
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 480         480  MAP Dataset  ...              A  hessianThreshold = 60
# 481         481  MAP Dataset  ...              A  hessianThreshold = 60
# 482         482  MAP Dataset  ...              A  hessianThreshold = 60
# 483         483  MAP Dataset  ...              A  hessianThreshold = 60
# 484         484  MAP Dataset  ...              A  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 595         595  MAP Dataset  ...              A  hessianThreshold = 60
# 596         596  MAP Dataset  ...              A  hessianThreshold = 60
# 597         597  MAP Dataset  ...              A  hessianThreshold = 60
# 598         598  MAP Dataset  ...              A  hessianThreshold = 60
# 599         599  MAP Dataset  ...              A  hessianThreshold = 60
#
# [120 rows x 6 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "hessianThreshold = 20"

# %%
SURF1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 480         480  MAP Dataset  ...              B  hessianThreshold = 20
# 481         481  MAP Dataset  ...              B  hessianThreshold = 20
# 482         482  MAP Dataset  ...              B  hessianThreshold = 20
# 483         483  MAP Dataset  ...              B  hessianThreshold = 20
# 484         484  MAP Dataset  ...              B  hessianThreshold = 20
# ..          ...          ...  ...            ...                    ...
# 595         595  MAP Dataset  ...              B  hessianThreshold = 20
# 596         596  MAP Dataset  ...              B  hessianThreshold = 20
# 597         597  MAP Dataset  ...              B  hessianThreshold = 20
# 598         598  MAP Dataset  ...              B  hessianThreshold = 20
# 599         599  MAP Dataset  ...              B  hessianThreshold = 20
#
# [120 rows x 6 columns]

# %%
SURF2=df3.loc[(df3['Detector/Descriptor'] == "SURF")]

# %%
SURF2['Parameter'] = "hessianThreshold = 60"

# %%
SURF2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 480         480  MAP Dataset  ...              C  hessianThreshold = 60
# 481         481  MAP Dataset  ...              C  hessianThreshold = 60
# 482         482  MAP Dataset  ...              C  hessianThreshold = 60
# 483         483  MAP Dataset  ...              C  hessianThreshold = 60
# 484         484  MAP Dataset  ...              C  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 595         595  MAP Dataset  ...              C  hessianThreshold = 60
# 596         596  MAP Dataset  ...              C  hessianThreshold = 60
# 597         597  MAP Dataset  ...              C  hessianThreshold = 60
# 598         598  MAP Dataset  ...              C  hessianThreshold = 60
# 599         599  MAP Dataset  ...              C  hessianThreshold = 60
#
# [120 rows x 6 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1, SURF2])

# %%
ALL_SURF
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 480         480  MAP Dataset  ...              A  hessianThreshold = 60
# 481         481  MAP Dataset  ...              A  hessianThreshold = 60
# 482         482  MAP Dataset  ...              A  hessianThreshold = 60
# 483         483  MAP Dataset  ...              A  hessianThreshold = 60
# 484         484  MAP Dataset  ...              A  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 595         595  MAP Dataset  ...              C  hessianThreshold = 60
# 596         596  MAP Dataset  ...              C  hessianThreshold = 60
# 597         597  MAP Dataset  ...              C  hessianThreshold = 60
# 598         598  MAP Dataset  ...              C  hessianThreshold = 60
# 599         599  MAP Dataset  ...              C  hessianThreshold = 60
#
# [360 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 240         240  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 243         243  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 244         244  MAP Dataset  ...              A  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 355         355  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 357         357  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 358         358  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 359         359  MAP Dataset  ...              A  Threshold=60, Octaves=6
#
# [120 rows x 6 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 240         240  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 243         243  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 244         244  MAP Dataset  ...              B  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 355         355  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 357         357  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 358         358  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 359         359  MAP Dataset  ...              B  Threshold=60, Octaves=6
#
# [120 rows x 6 columns]

# %%
FREAK2=df3.loc[(df3['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK2['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 240         240  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 243         243  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 244         244  MAP Dataset  ...              C  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 355         355  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 357         357  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 358         358  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 359         359  MAP Dataset  ...              C  Threshold=60, Octaves=6
#
# [120 rows x 6 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1, FREAK2])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 240         240  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 243         243  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 244         244  MAP Dataset  ...              A  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 355         355  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 357         357  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 358         358  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 359         359  MAP Dataset  ...              C  Threshold=60, Octaves=6
#
# [360 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 475         475  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 476         476  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 477         477  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 478         478  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 479         479  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 475         475  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 476         476  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 477         477  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 478         478  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 479         479  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
SIFT2=df3.loc[(df3['Detector/Descriptor'] == "SIFT")]

# %%
SIFT2['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT2
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 475         475  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 476         476  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 477         477  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 478         478  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 479         479  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1, SIFT2])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 360         360  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 361         361  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 362         362  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 363         363  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 364         364  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 475         475  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 476         476  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 477         477  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 478         478  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 479         479  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [360 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "Threshold=60"

# %%
FAST
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 120         120  MAP Dataset  ...              A  Threshold=60
# 121         121  MAP Dataset  ...              A  Threshold=60
# 122         122  MAP Dataset  ...              A  Threshold=60
# 123         123  MAP Dataset  ...              A  Threshold=60
# 124         124  MAP Dataset  ...              A  Threshold=60
# ..          ...          ...  ...            ...           ...
# 235         235  MAP Dataset  ...              A  Threshold=60
# 236         236  MAP Dataset  ...              A  Threshold=60
# 237         237  MAP Dataset  ...              A  Threshold=60
# 238         238  MAP Dataset  ...              A  Threshold=60
# 239         239  MAP Dataset  ...              A  Threshold=60
#
# [120 rows x 6 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "Threshold=40"

# %%
FAST1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 120         120  MAP Dataset  ...              B  Threshold=40
# 121         121  MAP Dataset  ...              B  Threshold=40
# 122         122  MAP Dataset  ...              B  Threshold=40
# 123         123  MAP Dataset  ...              B  Threshold=40
# 124         124  MAP Dataset  ...              B  Threshold=40
# ..          ...          ...  ...            ...           ...
# 235         235  MAP Dataset  ...              B  Threshold=40
# 236         236  MAP Dataset  ...              B  Threshold=40
# 237         237  MAP Dataset  ...              B  Threshold=40
# 238         238  MAP Dataset  ...              B  Threshold=40
# 239         239  MAP Dataset  ...              B  Threshold=40
#
# [120 rows x 6 columns]

# %%
FAST2=df3.loc[(df3['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST2['Parameter'] = "Threshold=60"

# %%
FAST2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 120         120  MAP Dataset  ...              C  Threshold=60
# 121         121  MAP Dataset  ...              C  Threshold=60
# 122         122  MAP Dataset  ...              C  Threshold=60
# 123         123  MAP Dataset  ...              C  Threshold=60
# 124         124  MAP Dataset  ...              C  Threshold=60
# ..          ...          ...  ...            ...           ...
# 235         235  MAP Dataset  ...              C  Threshold=60
# 236         236  MAP Dataset  ...              C  Threshold=60
# 237         237  MAP Dataset  ...              C  Threshold=60
# 238         238  MAP Dataset  ...              C  Threshold=60
# 239         239  MAP Dataset  ...              C  Threshold=60
#
# [120 rows x 6 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1, FAST2])

# %%
ALL_FAST
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 120         120  MAP Dataset  ...              A  Threshold=40
# 121         121  MAP Dataset  ...              A  Threshold=40
# 122         122  MAP Dataset  ...              A  Threshold=40
# 123         123  MAP Dataset  ...              A  Threshold=40
# 124         124  MAP Dataset  ...              A  Threshold=40
# ..          ...          ...  ...            ...           ...
# 235         235  MAP Dataset  ...              C  Threshold=60
# 236         236  MAP Dataset  ...              C  Threshold=60
# 237         237  MAP Dataset  ...              C  Threshold=60
# 238         238  MAP Dataset  ...              C  Threshold=60
# 239         239  MAP Dataset  ...              C  Threshold=60
#
# [360 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations')
