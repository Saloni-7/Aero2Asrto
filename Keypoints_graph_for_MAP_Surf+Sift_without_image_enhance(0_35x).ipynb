# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_MAP_Surf+sift_without image enhancement(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_surf+sift_without image enhancement(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_MAP_surf+sift_without image enhancement(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...            SURF+SIFT             A
# 1            1  MAP Dataset  ...            SURF+SIFT             A
# 2            2  MAP Dataset  ...            SURF+SIFT             A
# 3            3  MAP Dataset  ...            SURF+SIFT             A
# 4            4  MAP Dataset  ...            SURF+SIFT             A
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...            SURF+SIFT             A
# 96          96  MAP Dataset  ...            SURF+SIFT             A
# 97          97  MAP Dataset  ...            SURF+SIFT             A
# 98          98  MAP Dataset  ...            SURF+SIFT             A
# 99          99  MAP Dataset  ...            SURF+SIFT             A
#
# [100 rows x 5 columns]

# %%
df1['Parameter'] = "Surf:hessianThreshold =80, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 95          95  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 99          99  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
#
# [100 rows x 6 columns]

# %%
df2
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...            SURF+SIFT             B
# 1            1  MAP Dataset  ...            SURF+SIFT             B
# 2            2  MAP Dataset  ...            SURF+SIFT             B
# 3            3  MAP Dataset  ...            SURF+SIFT             B
# 4            4  MAP Dataset  ...            SURF+SIFT             B
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...            SURF+SIFT             B
# 96          96  MAP Dataset  ...            SURF+SIFT             B
# 97          97  MAP Dataset  ...            SURF+SIFT             B
# 98          98  MAP Dataset  ...            SURF+SIFT             B
# 99          99  MAP Dataset  ...            SURF+SIFT             B
#
# [100 rows x 5 columns]

# %%
df2['Parameter'] = "Surf:hessianThreshold =60, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 95          95  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 99          99  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
#
# [100 rows x 6 columns]

# %%
df3
# Out:
#     Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0            0  MAP Dataset  ...            SURF+SIFT             C
# 1            1  MAP Dataset  ...            SURF+SIFT             C
# 2            2  MAP Dataset  ...            SURF+SIFT             C
# 3            3  MAP Dataset  ...            SURF+SIFT             C
# 4            4  MAP Dataset  ...            SURF+SIFT             C
# ..         ...          ...  ...                  ...           ...
# 95          95  MAP Dataset  ...            SURF+SIFT             C
# 96          96  MAP Dataset  ...            SURF+SIFT             C
# 97          97  MAP Dataset  ...            SURF+SIFT             C
# 98          98  MAP Dataset  ...            SURF+SIFT             C
# 99          99  MAP Dataset  ...            SURF+SIFT             C
#
# [100 rows x 5 columns]

# %%
df3['Parameter'] = "Surf:hessianThreshold =40, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 95          95  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 99          99  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
#
# [100 rows x 6 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 95          95  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 99          99  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
#
# [300 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations')
