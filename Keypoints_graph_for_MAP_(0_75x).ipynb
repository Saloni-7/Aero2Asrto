# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_5_MAP Dataset_changed parameter_(0.75x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_5_MAP Dataset_changed parameter_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           AGAST+SIFT             A
# 1             1  MAP Dataset  ...           AGAST+SIFT             A
# 2             2  MAP Dataset  ...           AGAST+SIFT             A
# 3             3  MAP Dataset  ...           AGAST+SIFT             A
# 4             4  MAP Dataset  ...           AGAST+SIFT             A
# ..          ...          ...  ...                  ...           ...
# 295         295  MAP Dataset  ...                 SURF             A
# 296         296  MAP Dataset  ...                 SURF             A
# 297         297  MAP Dataset  ...                 SURF             A
# 298         298  MAP Dataset  ...                 SURF             A
# 299         299  MAP Dataset  ...                 SURF             A
#
# [300 rows x 5 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "AGAST: Threshold = 60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 1            1  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 2            2  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 3            3  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 4            4  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 5            5  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 6            6  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 7            7  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 8            8  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 9            9  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 10          10  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 11          11  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 12          12  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 13          13  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 14          14  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 15          15  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 16          16  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 17          17  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 18          18  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 19          19  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 20          20  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 21          21  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 22          22  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 23          23  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 24          24  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 25          25  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 26          26  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 27          27  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 28          28  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 29          29  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 30          30  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 31          31  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 32          32  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 33          33  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 34          34  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 35          35  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 36          36  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 37          37  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 38          38  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 39          39  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 40          40  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 41          41  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 42          42  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 43          43  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 44          44  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 45          45  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 46          46  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 47          47  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 48          48  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 49          49  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 50          50  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 51          51  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 52          52  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 53          53  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 54          54  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 55          55  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 56          56  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 57          57  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 58          58  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 59          59  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
#
# [60 rows x 6 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           AGAST+SIFT             B
# 1             1  MAP Dataset  ...           AGAST+SIFT             B
# 2             2  MAP Dataset  ...           AGAST+SIFT             B
# 3             3  MAP Dataset  ...           AGAST+SIFT             B
# 4             4  MAP Dataset  ...           AGAST+SIFT             B
# ..          ...          ...  ...                  ...           ...
# 295         295  MAP Dataset  ...                 SURF             B
# 296         296  MAP Dataset  ...                 SURF             B
# 297         297  MAP Dataset  ...                 SURF             B
# 298         298  MAP Dataset  ...                 SURF             B
# 299         299  MAP Dataset  ...                 SURF             B
#
# [300 rows x 5 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "Agast: Threshold= 80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 1            1  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 2            2  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 3            3  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 4            4  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 5            5  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 6            6  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 7            7  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 8            8  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 9            9  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 10          10  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 11          11  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 12          12  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 13          13  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 14          14  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 15          15  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 16          16  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 17          17  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 18          18  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 19          19  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 20          20  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 21          21  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 22          22  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 23          23  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 24          24  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 25          25  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 26          26  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 27          27  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 28          28  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 29          29  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 30          30  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 31          31  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 32          32  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 33          33  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 34          34  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 35          35  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 36          36  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 37          37  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 38          38  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 39          39  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 40          40  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 41          41  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 42          42  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 43          43  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 44          44  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 45          45  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 46          46  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 47          47  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 48          48  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 49          49  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 50          50  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 51          51  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 52          52  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 53          53  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 54          54  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 55          55  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 56          56  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 57          57  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 58          58  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 59          59  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
#
# [60 rows x 6 columns]

# %%
ALL_AGAST=pd.concat([AGAST_SIFT, AGAST_SIFT1])

# %%
ALL_AGAST
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 1            1  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 2            2  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 3            3  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 4            4  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# ..         ...  ...                                                ...
# 55          55  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 56          56  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 57          57  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 58          58  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
# 59          59  ...  Agast: Threshold= 80; SIFT: nfeatures = 1000, ...
#
# [120 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=ALL_AGAST, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF")]

# %%
SURF['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 245         245  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 246         246  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 247         247  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 248         248  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 249         249  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 250         250  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 251         251  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 252         252  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 253         253  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 254         254  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 255         255  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 256         256  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 257         257  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 258         258  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 259         259  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 260         260  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 261         261  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 262         262  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 263         263  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 264         264  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 265         265  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 266         266  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 267         267  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 268         268  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 269         269  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 270         270  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 271         271  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 272         272  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 273         273  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 274         274  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 275         275  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 276         276  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 277         277  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 278         278  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 279         279  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 280         280  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 281         281  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 282         282  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 283         283  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 284         284  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 285         285  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 286         286  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 287         287  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 288         288  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 289         289  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 290         290  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 291         291  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 292         292  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 293         293  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 294         294  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 295         295  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 296         296  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 297         297  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 298         298  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 299         299  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [60 rows x 6 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 245         245  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 246         246  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 247         247  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 248         248  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 249         249  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 250         250  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 251         251  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 252         252  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 253         253  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 254         254  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 255         255  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 256         256  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 257         257  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 258         258  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 259         259  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 260         260  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 261         261  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 262         262  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 263         263  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 264         264  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 265         265  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 266         266  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 267         267  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 268         268  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 269         269  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 270         270  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 271         271  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 272         272  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 273         273  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 274         274  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 275         275  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 276         276  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 277         277  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 278         278  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 279         279  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 280         280  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 281         281  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 282         282  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 283         283  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 284         284  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 285         285  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 286         286  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 287         287  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 288         288  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 289         289  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 290         290  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 291         291  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 292         292  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 293         293  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 294         294  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 295         295  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 296         296  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 297         297  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 298         298  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 299         299  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [60 rows x 6 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1])

# %%
ALL_SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 295         295  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 296         296  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 297         297  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 298         298  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 299         299  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [120 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "BRISK: Threshold=60, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                       Parameter
# 120         120  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 121         121  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 122         122  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 123         123  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 124         124  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 125         125  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 126         126  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 127         127  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 128         128  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 129         129  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 130         130  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 131         131  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 132         132  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 133         133  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 134         134  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 135         135  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 136         136  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 137         137  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 138         138  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 139         139  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 140         140  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 141         141  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 142         142  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 143         143  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 144         144  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 145         145  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 146         146  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 147         147  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 148         148  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 149         149  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 150         150  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 151         151  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 152         152  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 153         153  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 154         154  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 155         155  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 156         156  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 157         157  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 158         158  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 159         159  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 160         160  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 161         161  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 162         162  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 163         163  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 164         164  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 165         165  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 166         166  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 167         167  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 168         168  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 169         169  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 170         170  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 171         171  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 172         172  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 173         173  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 174         174  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 175         175  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 176         176  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 177         177  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 178         178  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 179         179  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
#
# [60 rows x 6 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "BRISK: Threshl=80, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                     Parameter
# 120         120  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 121         121  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 122         122  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 123         123  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 124         124  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 125         125  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 126         126  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 127         127  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 128         128  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 129         129  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 130         130  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 131         131  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 132         132  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 133         133  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 134         134  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 135         135  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 136         136  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 137         137  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 138         138  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 139         139  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 140         140  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 141         141  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 142         142  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 143         143  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 144         144  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 145         145  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 146         146  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 147         147  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 148         148  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 149         149  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 150         150  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 151         151  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 152         152  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 153         153  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 154         154  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 155         155  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 156         156  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 157         157  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 158         158  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 159         159  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 160         160  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 161         161  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 162         162  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 163         163  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 164         164  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 165         165  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 166         166  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 167         167  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 168         168  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 169         169  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 170         170  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 171         171  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 172         172  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 173         173  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 174         174  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 175         175  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 176         176  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 177         177  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 178         178  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
# 179         179  MAP Dataset  ...              B  BRISK: Threshl=80, Octaves=6
#
# [60 rows x 6 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                       Parameter
# 120         120  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 121         121  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 122         122  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 123         123  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 124         124  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                             ...
# 175         175  MAP Dataset  ...              B    BRISK: Threshl=80, Octaves=6
# 176         176  MAP Dataset  ...              B    BRISK: Threshl=80, Octaves=6
# 177         177  MAP Dataset  ...              B    BRISK: Threshl=80, Octaves=6
# 178         178  MAP Dataset  ...              B    BRISK: Threshl=80, Octaves=6
# 179         179  MAP Dataset  ...              B    BRISK: Threshl=80, Octaves=6
#
# [120 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 180         180  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 181         181  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 182         182  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 183         183  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 184         184  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 185         185  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 186         186  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 187         187  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 188         188  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 189         189  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 190         190  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 191         191  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 192         192  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 193         193  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 194         194  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 195         195  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 196         196  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 197         197  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 198         198  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 199         199  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 200         200  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 201         201  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 202         202  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 203         203  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 204         204  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 205         205  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 206         206  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 207         207  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 208         208  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 209         209  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 210         210  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 211         211  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 212         212  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 213         213  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 214         214  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 215         215  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 216         216  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 217         217  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 218         218  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 219         219  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 220         220  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 221         221  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 222         222  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 223         223  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 224         224  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 225         225  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 226         226  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 227         227  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 228         228  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 229         229  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 230         230  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 231         231  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 232         232  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 233         233  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 238         238  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 239         239  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [60 rows x 6 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 180         180  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 181         181  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 182         182  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 183         183  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 184         184  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 185         185  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 186         186  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 187         187  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 188         188  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 189         189  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 190         190  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 191         191  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 192         192  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 193         193  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 194         194  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 195         195  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 196         196  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 197         197  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 198         198  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 199         199  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 200         200  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 201         201  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 202         202  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 203         203  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 204         204  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 205         205  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 206         206  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 207         207  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 208         208  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 209         209  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 210         210  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 211         211  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 212         212  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 213         213  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 214         214  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 215         215  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 216         216  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 217         217  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 218         218  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 219         219  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 220         220  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 221         221  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 222         222  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 223         223  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 224         224  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 225         225  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 226         226  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 227         227  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 228         228  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 229         229  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 230         230  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 231         231  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 232         232  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 233         233  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 238         238  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 239         239  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [60 rows x 6 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 180         180  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 181         181  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 182         182  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 183         183  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 184         184  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 238         238  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 239         239  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [120 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "FAST: Threshold=60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 60           60  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 61           61  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 62           62  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 63           63  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 64           64  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 65           65  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 66           66  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 67           67  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 68           68  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 69           69  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 70           70  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 71           71  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 72           72  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 73           73  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 74           74  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 75           75  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 76           76  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 77           77  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 78           78  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 79           79  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 80           80  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 81           81  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 82           82  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 83           83  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 84           84  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 85           85  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 86           86  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 87           87  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 88           88  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 89           89  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 90           90  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 91           91  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 92           92  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 93           93  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 94           94  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 95           95  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 96           96  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 97           97  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 98           98  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 99           99  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 100         100  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 101         101  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 102         102  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 103         103  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 104         104  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 105         105  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 106         106  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 107         107  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 108         108  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 109         109  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 110         110  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 111         111  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 112         112  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 113         113  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 114         114  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 115         115  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 116         116  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 117         117  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 118         118  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 119         119  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
#
# [60 rows x 6 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "FAST: Threshold=80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 60           60  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 61           61  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 62           62  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 63           63  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 64           64  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 65           65  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 66           66  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 67           67  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 68           68  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 69           69  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 70           70  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 71           71  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 72           72  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 73           73  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 74           74  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 75           75  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 76           76  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 77           77  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 78           78  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 79           79  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 80           80  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 81           81  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 82           82  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 83           83  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 84           84  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 85           85  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 86           86  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 87           87  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 88           88  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 89           89  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 90           90  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 91           91  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 92           92  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 93           93  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 94           94  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 95           95  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 96           96  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 97           97  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 98           98  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 99           99  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 100         100  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 101         101  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 102         102  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 103         103  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 104         104  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 105         105  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 106         106  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 107         107  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 108         108  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 109         109  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 110         110  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 111         111  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 112         112  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 113         113  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 114         114  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 115         115  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 116         116  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 117         117  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 118         118  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 119         119  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
#
# [60 rows x 6 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1])

# %%
ALL_FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 60           60  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 61           61  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 62           62  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 63           63  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 64           64  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 115         115  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 116         116  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 117         117  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 118         118  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 119         119  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
#
# [120 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for FAST+SIFT for different parameter combinations')
