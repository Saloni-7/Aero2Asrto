# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Rootsift_without image enhance(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Rootsift_without image enhance(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Rootsift_without image enhance(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...             ROOTSIFT             A
# 1            1  Small Village Dataset  ...             ROOTSIFT             A
# 2            2  Small Village Dataset  ...             ROOTSIFT             A
# 3            3  Small Village Dataset  ...             ROOTSIFT             A
# 4            4  Small Village Dataset  ...             ROOTSIFT             A
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...             ROOTSIFT             A
# 76          76  Small Village Dataset  ...             ROOTSIFT             A
# 77          77  Small Village Dataset  ...             ROOTSIFT             A
# 78          78  Small Village Dataset  ...             ROOTSIFT             A
# 79          79  Small Village Dataset  ...             ROOTSIFT             A
#
# [80 rows x 5 columns]

# %%
df1['Parameter'] = "Sift: nfeatures = 1000, nOctaveLayers = 4, contrastThreshold = 0.06, edgeThreshold = 12"

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# ..         ...  ...                                                ...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 79          79  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
#
# [80 rows x 6 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...             ROOTSIFT             B
# 1            1  Small Village Dataset  ...             ROOTSIFT             B
# 2            2  Small Village Dataset  ...             ROOTSIFT             B
# 3            3  Small Village Dataset  ...             ROOTSIFT             B
# 4            4  Small Village Dataset  ...             ROOTSIFT             B
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...             ROOTSIFT             B
# 76          76  Small Village Dataset  ...             ROOTSIFT             B
# 77          77  Small Village Dataset  ...             ROOTSIFT             B
# 78          78  Small Village Dataset  ...             ROOTSIFT             B
# 79          79  Small Village Dataset  ...             ROOTSIFT             B
#
# [80 rows x 5 columns]

# %%
df2['Parameter'] = "Sift: nfeatures = 2000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10"

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 1            1  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 2            2  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 3            3  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 4            4  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# ..         ...  ...                                                ...
# 75          75  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
# 79          79  ...  Sift: nfeatures = 2000, nOctaveLayers = 3, con...
#
# [80 rows x 6 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...             ROOTSIFT             C
# 1            1  Small Village Dataset  ...             ROOTSIFT             C
# 2            2  Small Village Dataset  ...             ROOTSIFT             C
# 3            3  Small Village Dataset  ...             ROOTSIFT             C
# 4            4  Small Village Dataset  ...             ROOTSIFT             C
# ..         ...                    ...  ...                  ...           ...
# 75          75  Small Village Dataset  ...             ROOTSIFT             C
# 76          76  Small Village Dataset  ...             ROOTSIFT             C
# 77          77  Small Village Dataset  ...             ROOTSIFT             C
# 78          78  Small Village Dataset  ...             ROOTSIFT             C
# 79          79  Small Village Dataset  ...             ROOTSIFT             C
#
# [80 rows x 5 columns]

# %%
df3['Parameter'] = "Sift: nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 8"

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# ..         ...  ...                                                ...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 79          79  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
#
# [80 rows x 6 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 1            1  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 2            2  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 3            3  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# 4            4  ...  Sift: nfeatures = 1000, nOctaveLayers = 4, con...
# ..         ...  ...                                                ...
# 75          75  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 76          76  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 77          77  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 78          78  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
# 79          79  ...  Sift: nfeatures = 1000, nOctaveLayers = 3, con...
#
# [240 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for ROOTSIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for ROOTSIFT for different parameter combinations')
