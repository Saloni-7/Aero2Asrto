# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_Small Village_Sutf+Sift_without image enhance(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_Small Village_Sutf+Sift_without image enhance(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_Small Village_Sutf+Sift_without image enhance(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.030387             A
# 1            1  Small Village Dataset  ...  0.026541             A
# 2            2  Small Village Dataset  ...  0.008499             A
# 3            3  Small Village Dataset  ...  0.007858             A
# 4            4  Small Village Dataset  ...  0.016845             A
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.018892             A
# 95          95  Small Village Dataset  ...  0.022683             A
# 96          96  Small Village Dataset  ...  0.044534             A
# 97          97  Small Village Dataset  ...  0.053092             A
# 98          98  Small Village Dataset  ...  0.066798             A
#
# [99 rows x 9 columns]

# %%
df1['Parameter'] = "Surf:hessianThreshold =40 "

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                   Parameter
# 0            0  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 1            1  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 2            2  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 3            3  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 4            4  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# ..         ...                    ...  ...            ...                         ...
# 94          94  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 95          95  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 96          96  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 97          97  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 98          98  Small Village Dataset  ...              A  Surf:hessianThreshold =40
#
# [99 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.038383             B
# 1            1  Small Village Dataset  ...  0.034581             B
# 2            2  Small Village Dataset  ...  0.010024             B
# 3            3  Small Village Dataset  ...  0.008532             B
# 4            4  Small Village Dataset  ...  0.017799             B
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.020950             B
# 95          95  Small Village Dataset  ...  0.022061             B
# 96          96  Small Village Dataset  ...  0.054248             B
# 97          97  Small Village Dataset  ...  0.042927             B
# 98          98  Small Village Dataset  ...  0.074886             B
#
# [99 rows x 9 columns]

# %%
df2['Parameter'] = "Surf:hessianThreshold =60"

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 1            1  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 2            2  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 3            3  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 4            4  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# ..         ...                    ...  ...            ...                        ...
# 94          94  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 95          95  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 96          96  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 97          97  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 98          98  Small Village Dataset  ...              B  Surf:hessianThreshold =60
#
# [99 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.031839             C
# 1            1  Small Village Dataset  ...  0.033192             C
# 2            2  Small Village Dataset  ...  0.012085             C
# 3            3  Small Village Dataset  ...  0.009230             C
# 4            4  Small Village Dataset  ...  0.019235             C
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.024127             C
# 95          95  Small Village Dataset  ...  0.026816             C
# 96          96  Small Village Dataset  ...  0.057787             C
# 97          97  Small Village Dataset  ...  0.047572             C
# 98          98  Small Village Dataset  ...  0.086024             C
#
# [99 rows x 9 columns]

# %%
df3['Parameter'] = "Surf:hessianThreshold =80"

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 1            1  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 2            2  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 3            3  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 4            4  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# ..         ...                    ...  ...            ...                        ...
# 94          94  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 95          95  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 96          96  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 97          97  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 98          98  Small Village Dataset  ...              C  Surf:hessianThreshold =80
#
# [99 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                   Parameter
# 0            0  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 1            1  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 2            2  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 3            3  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 4            4  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# ..         ...                    ...  ...            ...                         ...
# 94          94  Small Village Dataset  ...              C   Surf:hessianThreshold =80
# 95          95  Small Village Dataset  ...              C   Surf:hessianThreshold =80
# 96          96  Small Village Dataset  ...              C   Surf:hessianThreshold =80
# 97          97  Small Village Dataset  ...              C   Surf:hessianThreshold =80
# 98          98  Small Village Dataset  ...              C   Surf:hessianThreshold =80
#
# [297 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF+SIFT for different parameter combinations')
