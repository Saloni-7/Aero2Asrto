# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_Small Village_ORB_without image enhance(0.75x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_Small Village_ORB_without image enhance(0.75x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_Small Village_ORB_without image enhance(0.75x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.002275             A
# 1            1  Small Village Dataset  ...  0.001950             A
# 2            2  Small Village Dataset  ...  0.000800             A
# 3            3  Small Village Dataset  ...  0.000200             A
# 4            4  Small Village Dataset  ...  0.000850             A
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.000925             A
# 95          95  Small Village Dataset  ...  0.002475             A
# 96          96  Small Village Dataset  ...  0.003200             A
# 97          97  Small Village Dataset  ...  0.002675             A
# 98          98  Small Village Dataset  ...  0.003650             A
#
# [99 rows x 9 columns]

# %%
df1['Parameter'] = "nfeatures= 40000 "

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName          Parameter
# 0            0  Small Village Dataset  ...              A  nfeatures= 40000
# 1            1  Small Village Dataset  ...              A  nfeatures= 40000
# 2            2  Small Village Dataset  ...              A  nfeatures= 40000
# 3            3  Small Village Dataset  ...              A  nfeatures= 40000
# 4            4  Small Village Dataset  ...              A  nfeatures= 40000
# ..         ...                    ...  ...            ...                ...
# 94          94  Small Village Dataset  ...              A  nfeatures= 40000
# 95          95  Small Village Dataset  ...              A  nfeatures= 40000
# 96          96  Small Village Dataset  ...              A  nfeatures= 40000
# 97          97  Small Village Dataset  ...              A  nfeatures= 40000
# 98          98  Small Village Dataset  ...              A  nfeatures= 40000
#
# [99 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.001783             B
# 1            1  Small Village Dataset  ...  0.001817             B
# 2            2  Small Village Dataset  ...  0.000583             B
# 3            3  Small Village Dataset  ...  0.000117             B
# 4            4  Small Village Dataset  ...  0.000633             B
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.000856             B
# 95          95  Small Village Dataset  ...  0.002050             B
# 96          96  Small Village Dataset  ...  0.003067             B
# 97          97  Small Village Dataset  ...  0.001983             B
# 98          98  Small Village Dataset  ...  0.003183             B
#
# [99 rows x 9 columns]

# %%
df2['Parameter'] = "nfeatures= 60000"

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName         Parameter
# 0            0  Small Village Dataset  ...              B  nfeatures= 60000
# 1            1  Small Village Dataset  ...              B  nfeatures= 60000
# 2            2  Small Village Dataset  ...              B  nfeatures= 60000
# 3            3  Small Village Dataset  ...              B  nfeatures= 60000
# 4            4  Small Village Dataset  ...              B  nfeatures= 60000
# ..         ...                    ...  ...            ...               ...
# 94          94  Small Village Dataset  ...              B  nfeatures= 60000
# 95          95  Small Village Dataset  ...              B  nfeatures= 60000
# 96          96  Small Village Dataset  ...              B  nfeatures= 60000
# 97          97  Small Village Dataset  ...              B  nfeatures= 60000
# 98          98  Small Village Dataset  ...              B  nfeatures= 60000
#
# [99 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.001625             C
# 1            1  Small Village Dataset  ...  0.001437             C
# 2            2  Small Village Dataset  ...  0.000650             C
# 3            3  Small Village Dataset  ...  0.000088             C
# 4            4  Small Village Dataset  ...  0.000637             C
# ..         ...                    ...  ...       ...           ...
# 94          94  Small Village Dataset  ...  0.000903             C
# 95          95  Small Village Dataset  ...  0.001800             C
# 96          96  Small Village Dataset  ...  0.002862             C
# 97          97  Small Village Dataset  ...  0.001788             C
# 98          98  Small Village Dataset  ...  0.003075             C
#
# [99 rows x 9 columns]

# %%
df3['Parameter'] = "nfeatures= 80000"

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName         Parameter
# 0            0  Small Village Dataset  ...              C  nfeatures= 80000
# 1            1  Small Village Dataset  ...              C  nfeatures= 80000
# 2            2  Small Village Dataset  ...              C  nfeatures= 80000
# 3            3  Small Village Dataset  ...              C  nfeatures= 80000
# 4            4  Small Village Dataset  ...              C  nfeatures= 80000
# ..         ...                    ...  ...            ...               ...
# 94          94  Small Village Dataset  ...              C  nfeatures= 80000
# 95          95  Small Village Dataset  ...              C  nfeatures= 80000
# 96          96  Small Village Dataset  ...              C  nfeatures= 80000
# 97          97  Small Village Dataset  ...              C  nfeatures= 80000
# 98          98  Small Village Dataset  ...              C  nfeatures= 80000
#
# [99 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName          Parameter
# 0            0  Small Village Dataset  ...              A  nfeatures= 40000
# 1            1  Small Village Dataset  ...              A  nfeatures= 40000
# 2            2  Small Village Dataset  ...              A  nfeatures= 40000
# 3            3  Small Village Dataset  ...              A  nfeatures= 40000
# 4            4  Small Village Dataset  ...              A  nfeatures= 40000
# ..         ...                    ...  ...            ...                ...
# 94          94  Small Village Dataset  ...              C   nfeatures= 80000
# 95          95  Small Village Dataset  ...              C   nfeatures= 80000
# 96          96  Small Village Dataset  ...              C   nfeatures= 80000
# 97          97  Small Village Dataset  ...              C   nfeatures= 80000
# 98          98  Small Village Dataset  ...              C   nfeatures= 80000
#
# [297 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for ORB for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for ORB for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for ORB for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for ORB for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for ORB for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for ORB for different parameter combinations')
