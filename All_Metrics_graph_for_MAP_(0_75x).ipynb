# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_5_MAP_changed parameter_(0.75x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/All_metrics_5_MAP_changed parameter_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.080000             A
# 1             1  MAP Dataset  ...  0.052000             A
# 2             2  MAP Dataset  ...  0.084958             A
# 3             3  MAP Dataset  ...  0.093500             A
# 4             4  MAP Dataset  ...  0.099000             A
# ..          ...          ...  ...       ...           ...
# 290         290  MAP Dataset  ...  0.417754             A
# 291         291  MAP Dataset  ...  0.000044             A
# 292         292  MAP Dataset  ...  0.105053             A
# 293         293  MAP Dataset  ...  0.225051             A
# 294         294  MAP Dataset  ...  0.248220             A
#
# [295 rows x 9 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "AGAST: Threshold = 60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 1            1  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 2            2  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 3            3  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 4            4  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 5            5  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 6            6  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 7            7  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 8            8  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 9            9  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 10          10  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 11          11  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 12          12  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 13          13  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 14          14  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 15          15  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 16          16  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 17          17  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 18          18  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 19          19  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 20          20  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 21          21  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 22          22  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 23          23  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 24          24  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 25          25  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 26          26  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 27          27  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 28          28  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 29          29  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 30          30  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 31          31  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 32          32  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 33          33  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 34          34  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 35          35  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 36          36  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 37          37  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 38          38  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 39          39  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 40          40  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 41          41  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 42          42  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 43          43  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 44          44  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 45          45  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 46          46  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 47          47  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 48          48  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 49          49  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 50          50  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 51          51  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 52          52  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 53          53  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 54          54  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 55          55  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 56          56  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 57          57  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 58          58  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
#
# [59 rows x 10 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.077000             B
# 1             1  MAP Dataset  ...  0.053000             B
# 2             2  MAP Dataset  ...  0.083458             B
# 3             3  MAP Dataset  ...  0.076500             B
# 4             4  MAP Dataset  ...  0.097500             B
# ..          ...          ...  ...       ...           ...
# 290         290  MAP Dataset  ...  0.369450             B
# 291         291  MAP Dataset  ...  0.000091             B
# 292         292  MAP Dataset  ...  0.096958             B
# 293         293  MAP Dataset  ...  0.193387             B
# 294         294  MAP Dataset  ...  0.209189             B
#
# [295 rows x 9 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "AGAST: Threshold = 80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
AGAST_SIFT1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 1            1  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 2            2  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 3            3  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 4            4  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 5            5  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 6            6  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 7            7  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 8            8  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 9            9  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 10          10  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 11          11  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 12          12  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 13          13  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 14          14  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 15          15  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 16          16  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 17          17  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 18          18  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 19          19  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 20          20  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 21          21  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 22          22  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 23          23  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 24          24  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 25          25  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 26          26  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 27          27  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 28          28  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 29          29  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 30          30  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 31          31  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 32          32  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 33          33  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 34          34  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 35          35  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 36          36  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 37          37  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 38          38  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 39          39  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 40          40  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 41          41  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 42          42  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 43          43  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 44          44  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 45          45  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 46          46  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 47          47  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 48          48  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 49          49  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 50          50  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 51          51  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 52          52  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 53          53  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 54          54  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 55          55  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 56          56  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 57          57  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 58          58  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
#
# [59 rows x 10 columns]

# %%
df=pd.concat([AGAST_SIFT, AGAST_SIFT1])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 1            1  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 2            2  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 3            3  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# 4            4  ...  AGAST: Threshold = 60; SIFT: nfeatures = 1000,...
# ..         ...  ...                                                ...
# 54          54  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 55          55  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 56          56  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 57          57  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
# 58          58  ...  AGAST: Threshold = 80; SIFT: nfeatures = 1000,...
#
# [118 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matchesfor AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matchesfor AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF")]

# %%
SURF['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 236         236  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 237         237  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 245         245  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 246         246  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 247         247  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 248         248  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 249         249  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 250         250  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 251         251  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 252         252  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 253         253  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 254         254  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 255         255  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 256         256  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 257         257  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 258         258  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 259         259  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 260         260  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 261         261  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 262         262  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 263         263  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 264         264  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 265         265  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 266         266  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 267         267  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 268         268  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 269         269  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 270         270  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 271         271  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 272         272  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 273         273  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 274         274  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 275         275  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 276         276  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 277         277  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 278         278  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 279         279  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 280         280  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 281         281  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 282         282  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 283         283  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 284         284  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 285         285  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 286         286  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 287         287  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 288         288  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 289         289  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 290         290  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 291         291  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 292         292  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 293         293  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 294         294  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [59 rows x 10 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "SURF: nOctaves = 3, hessianThreshold = 60 ,upright=1"

# %%
SURF1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 236         236  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 237         237  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 241         241  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 242         242  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 243         243  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 244         244  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 245         245  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 246         246  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 247         247  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 248         248  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 249         249  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 250         250  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 251         251  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 252         252  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 253         253  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 254         254  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 255         255  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 256         256  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 257         257  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 258         258  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 259         259  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 260         260  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 261         261  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 262         262  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 263         263  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 264         264  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 265         265  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 266         266  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 267         267  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 268         268  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 269         269  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 270         270  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 271         271  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 272         272  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 273         273  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 274         274  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 275         275  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 276         276  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 277         277  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 278         278  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 279         279  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 280         280  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 281         281  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 282         282  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 283         283  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 284         284  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 285         285  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 286         286  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 287         287  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 288         288  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 289         289  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 290         290  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 291         291  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 292         292  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 293         293  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 294         294  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [59 rows x 10 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1])

# %%
ALL_SURF
# Out:
#      Unnamed: 0  ...                                          Parameter
# 236         236  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 237         237  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 238         238  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 239         239  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 240         240  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# ..          ...  ...                                                ...
# 290         290  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 291         291  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 292         292  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 293         293  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
# 294         294  ...  SURF: nOctaves = 3, hessianThreshold = 60 ,upr...
#
# [118 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "BRISK: Threshold=60, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                       Parameter
# 118         118  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 119         119  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 120         120  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 121         121  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 122         122  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 123         123  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 124         124  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 125         125  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 126         126  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 127         127  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 128         128  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 129         129  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 130         130  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 131         131  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 132         132  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 133         133  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 134         134  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 135         135  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 136         136  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 137         137  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 138         138  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 139         139  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 140         140  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 141         141  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 142         142  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 143         143  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 144         144  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 145         145  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 146         146  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 147         147  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 148         148  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 149         149  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 150         150  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 151         151  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 152         152  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 153         153  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 154         154  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 155         155  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 156         156  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 157         157  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 158         158  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 159         159  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 160         160  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 161         161  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 162         162  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 163         163  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 164         164  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 165         165  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 166         166  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 167         167  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 168         168  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 169         169  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 170         170  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 171         171  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 172         172  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 173         173  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 174         174  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 175         175  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 176         176  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
#
# [59 rows x 10 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "BRISK: Threshold=80, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                       Parameter
# 118         118  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 119         119  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 120         120  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 121         121  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 122         122  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 123         123  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 124         124  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 125         125  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 126         126  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 127         127  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 128         128  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 129         129  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 130         130  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 131         131  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 132         132  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 133         133  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 134         134  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 135         135  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 136         136  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 137         137  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 138         138  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 139         139  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 140         140  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 141         141  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 142         142  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 143         143  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 144         144  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 145         145  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 146         146  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 147         147  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 148         148  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 149         149  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 150         150  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 151         151  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 152         152  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 153         153  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 154         154  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 155         155  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 156         156  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 157         157  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 158         158  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 159         159  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 160         160  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 161         161  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 162         162  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 163         163  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 164         164  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 165         165  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 166         166  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 167         167  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 168         168  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 169         169  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 170         170  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 171         171  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 172         172  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 173         173  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 174         174  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 175         175  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 176         176  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
#
# [59 rows x 10 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                       Parameter
# 118         118  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 119         119  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 120         120  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 121         121  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# 122         122  MAP Dataset  ...              A  BRISK: Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                             ...
# 172         172  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 173         173  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 174         174  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 175         175  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
# 176         176  MAP Dataset  ...              B  BRISK: Threshold=80, Octaves=6
#
# [118 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 59           59  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 60           60  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 61           61  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 62           62  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 63           63  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 64           64  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 65           65  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 66           66  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 67           67  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 68           68  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 69           69  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 70           70  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 71           71  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 72           72  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 73           73  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 74           74  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 75           75  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 76           76  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 77           77  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 78           78  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 79           79  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 80           80  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 81           81  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 82           82  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 83           83  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 84           84  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 85           85  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 86           86  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 87           87  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 88           88  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 89           89  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 90           90  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 91           91  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 92           92  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 93           93  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 94           94  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 95           95  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 96           96  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 97           97  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 98           98  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 99           99  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 100         100  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 101         101  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 102         102  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 103         103  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 104         104  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 105         105  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 106         106  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 107         107  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 108         108  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 109         109  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 110         110  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 111         111  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 112         112  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 113         113  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 114         114  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 115         115  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 116         116  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 117         117  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [59 rows x 10 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 59           59  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 60           60  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 61           61  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 62           62  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 63           63  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 64           64  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 65           65  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 66           66  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 67           67  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 68           68  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 69           69  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 70           70  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 71           71  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 72           72  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 73           73  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 74           74  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 75           75  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 76           76  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 77           77  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 78           78  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 79           79  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 80           80  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 81           81  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 82           82  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 83           83  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 84           84  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 85           85  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 86           86  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 87           87  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 88           88  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 89           89  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 90           90  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 91           91  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 92           92  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 93           93  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 94           94  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 95           95  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 96           96  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 97           97  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 98           98  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 99           99  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 100         100  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 101         101  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 102         102  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 103         103  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 104         104  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 105         105  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 106         106  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 107         107  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 108         108  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 109         109  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 110         110  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 111         111  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 112         112  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 113         113  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 114         114  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 115         115  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 116         116  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 117         117  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [59 rows x 10 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 59           59  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 60           60  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 61           61  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 62           62  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 63           63  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 113         113  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 114         114  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 115         115  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 116         116  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 117         117  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [118 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "FAST: Threshold=60; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 177         177  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 178         178  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 179         179  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 180         180  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 181         181  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 182         182  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 183         183  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 184         184  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 185         185  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 186         186  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 187         187  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 188         188  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 189         189  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 190         190  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 191         191  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 192         192  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 193         193  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 194         194  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 195         195  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 196         196  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 197         197  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 198         198  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 199         199  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 200         200  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 201         201  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 202         202  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 203         203  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 204         204  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 205         205  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 206         206  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 207         207  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 208         208  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 209         209  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 210         210  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 211         211  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 212         212  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 213         213  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 214         214  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 215         215  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 216         216  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 217         217  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 218         218  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 219         219  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 220         220  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 221         221  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 222         222  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 223         223  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 224         224  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 225         225  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 226         226  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 227         227  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 228         228  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 229         229  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 230         230  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 231         231  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 232         232  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 233         233  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 234         234  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 235         235  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
#
# [59 rows x 10 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "FAST: Threshold=80; SIFT: nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
FAST1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 177         177  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 178         178  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 179         179  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 180         180  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 181         181  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 182         182  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 183         183  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 184         184  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 185         185  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 186         186  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 187         187  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 188         188  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 189         189  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 190         190  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 191         191  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 192         192  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 193         193  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 194         194  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 195         195  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 196         196  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 197         197  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 198         198  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 199         199  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 200         200  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 201         201  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 202         202  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 203         203  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 204         204  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 205         205  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 206         206  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 207         207  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 208         208  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 209         209  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 210         210  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 211         211  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 212         212  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 213         213  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 214         214  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 215         215  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 216         216  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 217         217  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 218         218  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 219         219  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 220         220  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 221         221  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 222         222  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 223         223  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 224         224  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 225         225  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 226         226  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 227         227  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 228         228  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 229         229  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 230         230  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 231         231  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 232         232  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 233         233  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 234         234  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 235         235  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
#
# [59 rows x 10 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1])

# %%
ALL_FAST
# Out:
#      Unnamed: 0  ...                                          Parameter
# 177         177  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 178         178  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 179         179  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 180         180  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# 181         181  ...  FAST: Threshold=60; SIFT: nfeatures = 1000, co...
# ..          ...  ...                                                ...
# 231         231  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 232         232  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 233         233  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 234         234  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
# 235         235  ...  FAST: Threshold=80; SIFT: nfeatures = 1000, co...
#
# [118 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for FAST+SIFT for different parameter combinations')
