# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_Superpoint_(0.35x) without image enhance_1.csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_Superpoint_(0.35x) without image enhance_2.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_MAP Dataset_Superpoint_(0.35x) without image enhance_3.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           SUPERPOINT             A
# 1             1  MAP Dataset  ...           SUPERPOINT             A
# 2             2  MAP Dataset  ...           SUPERPOINT             A
# 3             3  MAP Dataset  ...           SUPERPOINT             A
# 4             4  MAP Dataset  ...           SUPERPOINT             A
# ..          ...          ...  ...                  ...           ...
# 115         115  MAP Dataset  ...           SUPERPOINT             A
# 116         116  MAP Dataset  ...           SUPERPOINT             A
# 117         117  MAP Dataset  ...           SUPERPOINT             A
# 118         118  MAP Dataset  ...           SUPERPOINT             A
# 119         119  MAP Dataset  ...           SUPERPOINT             A
#
# [120 rows x 5 columns]

# %%
df1['Parameter'] = "weights_path=weights_path,nms_dist = 3,conf_thresh = 0.01,nn_thresh=0.5 "

# %%
df1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 115         115  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 119         119  ...  weights_path=weights_path,nms_dist = 3,conf_th...
#
# [120 rows x 6 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           SUPERPOINT             B
# 1             1  MAP Dataset  ...           SUPERPOINT             B
# 2             2  MAP Dataset  ...           SUPERPOINT             B
# 3             3  MAP Dataset  ...           SUPERPOINT             B
# 4             4  MAP Dataset  ...           SUPERPOINT             B
# ..          ...          ...  ...                  ...           ...
# 235         235          NaN  ...                  NaN             B
# 236         236          NaN  ...                  NaN             B
# 237         237          NaN  ...                  NaN             B
# 238         238          NaN  ...                  NaN             B
# 239         239          NaN  ...                  NaN             B
#
# [240 rows x 5 columns]

# %%
df2['Parameter'] = "weights_path=weights_path,nms_dist = 3,conf_thresh = 0.03,nn_thresh=0.7"

# %%
df2
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 235         235  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 236         236  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 237         237  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 238         238  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 239         239  ...  weights_path=weights_path,nms_dist = 3,conf_th...
#
# [240 rows x 6 columns]

# %%
df3
# Out:
#      Unnamed: 0      Dataset  ...  Detector/Descriptor ParameterName
# 0             0  MAP Dataset  ...           SUPERPOINT             C
# 1             1  MAP Dataset  ...           SUPERPOINT             C
# 2             2  MAP Dataset  ...           SUPERPOINT             C
# 3             3  MAP Dataset  ...           SUPERPOINT             C
# 4             4  MAP Dataset  ...           SUPERPOINT             C
# ..          ...          ...  ...                  ...           ...
# 115         115  MAP Dataset  ...           SUPERPOINT             C
# 116         116  MAP Dataset  ...           SUPERPOINT             C
# 117         117  MAP Dataset  ...           SUPERPOINT             C
# 118         118  MAP Dataset  ...           SUPERPOINT             C
# 119         119  MAP Dataset  ...           SUPERPOINT             C
#
# [120 rows x 5 columns]

# %%
df3['Parameter'] = "weights_path=weights_path,nms_dist = 2,conf_thresh = 0.01,nn_thresh=0.4"

# %%
df3
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# ..          ...  ...                                                ...
# 115         115  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 119         119  ...  weights_path=weights_path,nms_dist = 2,conf_th...
#
# [120 rows x 6 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 115         115  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 119         119  ...  weights_path=weights_path,nms_dist = 2,conf_th...
#
# [480 rows x 6 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SUPERPOINT for different parameter combinations')
