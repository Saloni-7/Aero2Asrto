# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_MAP_Superpoint_(0.35x) without image enhance_1.csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/All_metrics_1_MAP_Superpoint_(0.35x) without image enhance_2.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_MAP_Superpoint_(0.35x) without image enhance_3.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.211077             A
# 1             1  MAP Dataset  ...  0.232887             A
# 2             2  MAP Dataset  ...  0.237540             A
# 3             3  MAP Dataset  ...  0.200071             A
# 4             4  MAP Dataset  ...  0.002224             A
# ..          ...          ...  ...       ...           ...
# 114         114  MAP Dataset  ...  0.325093             A
# 115         115  MAP Dataset  ...  0.372881             A
# 116         116  MAP Dataset  ...  0.360209             A
# 117         117  MAP Dataset  ...  0.426596             A
# 118         118  MAP Dataset  ...  0.005269             A
#
# [119 rows x 9 columns]

# %%
df1['Parameter'] = "weights_path=weights_path,nms_dist = 3,conf_thresh = 0.01,nn_thresh=0.5 "

# %%
df1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 114         114  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 115         115  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 3,conf_th...
#
# [119 rows x 10 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.224393             B
# 1             1  MAP Dataset  ...  0.217004             B
# 2             2  MAP Dataset  ...  0.222805             B
# 3             3  MAP Dataset  ...  0.218735             B
# 4             4  MAP Dataset  ...  0.003054             B
# ..          ...          ...  ...       ...           ...
# 114         114  MAP Dataset  ...  0.327869             B
# 115         115  MAP Dataset  ...  0.387402             B
# 116         116  MAP Dataset  ...  0.460218             B
# 117         117  MAP Dataset  ...  0.434713             B
# 118         118  MAP Dataset  ...  0.007440             B
#
# [119 rows x 9 columns]

# %%
df2['Parameter'] = "weights_path=weights_path,nms_dist = 3,conf_thresh = 0.03,nn_thresh=0.7"

# %%
df2
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 114         114  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 115         115  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 3,conf_th...
#
# [119 rows x 10 columns]

# %%
df3
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.246177             C
# 1             1  MAP Dataset  ...  0.205790             C
# 2             2  MAP Dataset  ...  0.226808             C
# 3             3  MAP Dataset  ...  0.181911             C
# 4             4  MAP Dataset  ...  0.002160             C
# ..          ...          ...  ...       ...           ...
# 114         114  MAP Dataset  ...  0.307692             C
# 115         115  MAP Dataset  ...  0.332962             C
# 116         116  MAP Dataset  ...  0.370984             C
# 117         117  MAP Dataset  ...  0.369407             C
# 118         118  MAP Dataset  ...  0.005149             C
#
# [119 rows x 9 columns]

# %%
df3['Parameter'] = "weights_path=weights_path,nms_dist = 2,conf_thresh = 0.01,nn_thresh=0.4"

# %%
df3
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# ..          ...  ...                                                ...
# 114         114  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 115         115  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 2,conf_th...
#
# [119 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#      Unnamed: 0  ...                                          Parameter
# 0             0  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 1             1  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 2             2  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 3             3  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# 4             4  ...  weights_path=weights_path,nms_dist = 3,conf_th...
# ..          ...  ...                                                ...
# 114         114  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 115         115  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 116         116  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 117         117  ...  weights_path=weights_path,nms_dist = 2,conf_th...
# 118         118  ...  weights_path=weights_path,nms_dist = 2,conf_th...
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for SUPERPOINT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SUPERPOINT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SUPERPOINT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SUPERPOINT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SUPERPOINT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SUPERPOINT for different parameter combinations')
