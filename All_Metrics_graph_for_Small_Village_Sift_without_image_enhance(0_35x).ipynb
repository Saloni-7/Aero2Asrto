# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_Small Village_Sift_without image enhance(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_Small Village_Sift_without image enhance(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_Small Village_Sift_without image enhance(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.084000             A
# 1            1  Small Village Dataset  ...  0.092000             A
# 2            2  Small Village Dataset  ...  0.089910             A
# 3            3  Small Village Dataset  ...  0.057000             A
# 4            4  Small Village Dataset  ...  0.059000             A
# ..         ...                    ...  ...       ...           ...
# 74          74  Small Village Dataset  ...  0.045000             A
# 75          75  Small Village Dataset  ...  0.061000             A
# 76          76  Small Village Dataset  ...  0.074000             A
# 77          77  Small Village Dataset  ...  0.007992             A
# 78          78  Small Village Dataset  ...  0.013000             A
#
# [79 rows x 9 columns]

# %%
df1['Parameter'] = "nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.06, edgeThreshold = 12 "

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 74          74  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [79 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.06850             B
# 1            1  Small Village Dataset  ...  0.09950             B
# 2            2  Small Village Dataset  ...  0.09750             B
# 3            3  Small Village Dataset  ...  0.04048             B
# 4            4  Small Village Dataset  ...  0.05900             B
# ..         ...                    ...  ...      ...           ...
# 74          74  Small Village Dataset  ...  0.04700             B
# 75          75  Small Village Dataset  ...  0.07300             B
# 76          76  Small Village Dataset  ...  0.05550             B
# 77          77  Small Village Dataset  ...  0.01700             B
# 78          78  Small Village Dataset  ...  0.00650             B
#
# [79 rows x 9 columns]

# %%
df2['Parameter'] = "nfeatures = 2000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10"

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 74          74  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 75          75  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 2000, nOctaveLayers = 3, contrastT...
#
# [79 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...   F-Score ParameterName
# 0            0  Small Village Dataset  ...  0.097000             C
# 1            1  Small Village Dataset  ...  0.108000             C
# 2            2  Small Village Dataset  ...  0.093000             C
# 3            3  Small Village Dataset  ...  0.046000             C
# 4            4  Small Village Dataset  ...  0.070000             C
# ..         ...                    ...  ...       ...           ...
# 74          74  Small Village Dataset  ...  0.040000             C
# 75          75  Small Village Dataset  ...  0.057000             C
# 76          76  Small Village Dataset  ...  0.065934             C
# 77          77  Small Village Dataset  ...  0.008000             C
# 78          78  Small Village Dataset  ...  0.007000             C
#
# [79 rows x 9 columns]

# %%
df3['Parameter'] = "nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 8"

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 74          74  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [79 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 1            1  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 2            2  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 3            3  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 4            4  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# ..         ...  ...                                                ...
# 74          74  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 75          75  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 76          76  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 77          77  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
# 78          78  ...  nfeatures = 1000, nOctaveLayers = 3, contrastT...
#
# [237 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF+SIFT for different parameter combinations')
