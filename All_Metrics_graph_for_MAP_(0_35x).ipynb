# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_5_MAP_Changed_Parameters_(0.35x)_4.csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/All_metrics_5_Freak,Sift,Surf,Agast,Fast(changed parameter)_MAP_120 image(0.35x).csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_5_Changed parameter_(0.35x)_3.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#      Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0             0  MAP Dataset  ...  0.089500             A
# 1             1  MAP Dataset  ...  0.079000             A
# 2             2  MAP Dataset  ...  0.061500             A
# 3             3  MAP Dataset  ...  0.037500             A
# 4             4  MAP Dataset  ...  0.005997             A
# ..          ...          ...  ...       ...           ...
# 590         590  MAP Dataset  ...  0.220728             A
# 591         591  MAP Dataset  ...  0.220321             A
# 592         592  MAP Dataset  ...  0.209448             A
# 593         593  MAP Dataset  ...  0.265157             A
# 594         594  MAP Dataset  ...  0.304476             A
#
# [595 rows x 9 columns]

# %%
AGAST_SIFT=df1.loc[(df1['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT['Parameter'] = "Agast Threshold= 60 "

# %%
AGAST_SIFT
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName             Parameter
# 0             0  MAP Dataset  ...              A  Agast Threshold= 60
# 1             1  MAP Dataset  ...              A  Agast Threshold= 60
# 2             2  MAP Dataset  ...              A  Agast Threshold= 60
# 3             3  MAP Dataset  ...              A  Agast Threshold= 60
# 4             4  MAP Dataset  ...              A  Agast Threshold= 60
# ..          ...          ...  ...            ...                   ...
# 114         114  MAP Dataset  ...              A  Agast Threshold= 60
# 115         115  MAP Dataset  ...              A  Agast Threshold= 60
# 116         116  MAP Dataset  ...              A  Agast Threshold= 60
# 117         117  MAP Dataset  ...              A  Agast Threshold= 60
# 118         118  MAP Dataset  ...              A  Agast Threshold= 60
#
# [119 rows x 10 columns]

# %%
df2
# Out:
#      Unnamed: 0      Dataset  ...    F-Score ParameterName
# 0             0  MAP Dataset  ...  38.791000             B
# 1             1  MAP Dataset  ...  41.017982             B
# 2             2  MAP Dataset  ...  36.929000             B
# 3             3  MAP Dataset  ...   9.968000             B
# 4             4  MAP Dataset  ...   0.008991             B
# ..          ...          ...  ...        ...           ...
# 590         590  MAP Dataset  ...   0.000607             B
# 591         591  MAP Dataset  ...   0.000749             B
# 592         592  MAP Dataset  ...   0.000695             B
# 593         593  MAP Dataset  ...   0.000599             B
# 594         594  MAP Dataset  ...   0.000486             B
#
# [595 rows x 9 columns]

# %%
AGAST_SIFT1=df2.loc[(df2['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT1['Parameter'] = "Agast Threshold= 40"

# %%
AGAST_SIFT1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName            Parameter
# 0             0  MAP Dataset  ...              B  Agast Threshold= 40
# 1             1  MAP Dataset  ...              B  Agast Threshold= 40
# 2             2  MAP Dataset  ...              B  Agast Threshold= 40
# 3             3  MAP Dataset  ...              B  Agast Threshold= 40
# 4             4  MAP Dataset  ...              B  Agast Threshold= 40
# ..          ...          ...  ...            ...                  ...
# 114         114  MAP Dataset  ...              B  Agast Threshold= 40
# 115         115  MAP Dataset  ...              B  Agast Threshold= 40
# 116         116  MAP Dataset  ...              B  Agast Threshold= 40
# 117         117  MAP Dataset  ...              B  Agast Threshold= 40
# 118         118  MAP Dataset  ...              B  Agast Threshold= 40
#
# [119 rows x 10 columns]

# %%
df3
# Out:
#      Unnamed: 0      Dataset  ...  F-Score ParameterName
# 0             0  MAP Dataset  ...      1.0             C
# 1             1  MAP Dataset  ...      1.0             C
# 2             2  MAP Dataset  ...      1.0             C
# 3             3  MAP Dataset  ...      1.0             C
# 4             4  MAP Dataset  ...      1.0             C
# ..          ...          ...  ...      ...           ...
# 590         590  MAP Dataset  ...      1.0             C
# 591         591  MAP Dataset  ...      1.0             C
# 592         592  MAP Dataset  ...      1.0             C
# 593         593  MAP Dataset  ...      1.0             C
# 594         594  MAP Dataset  ...      1.0             C
#
# [595 rows x 9 columns]

# %%
AGAST_SIFT2=df3.loc[(df3['Detector/Descriptor'] == "AGAST+SIFT")]

# %%
AGAST_SIFT2['Parameter'] = "Agast Threshold= 60"

# %%
AGAST_SIFT2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName            Parameter
# 0             0  MAP Dataset  ...              C  Agast Threshold= 60
# 1             1  MAP Dataset  ...              C  Agast Threshold= 60
# 2             2  MAP Dataset  ...              C  Agast Threshold= 60
# 3             3  MAP Dataset  ...              C  Agast Threshold= 60
# 4             4  MAP Dataset  ...              C  Agast Threshold= 60
# ..          ...          ...  ...            ...                  ...
# 114         114  MAP Dataset  ...              C  Agast Threshold= 60
# 115         115  MAP Dataset  ...              C  Agast Threshold= 60
# 116         116  MAP Dataset  ...              C  Agast Threshold= 60
# 117         117  MAP Dataset  ...              C  Agast Threshold= 60
# 118         118  MAP Dataset  ...              C  Agast Threshold= 60
#
# [119 rows x 10 columns]

# %%
df=pd.concat([AGAST_SIFT, AGAST_SIFT1, AGAST_SIFT2])

# %%
df
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName             Parameter
# 0             0  MAP Dataset  ...              A  Agast Threshold= 60
# 1             1  MAP Dataset  ...              A  Agast Threshold= 60
# 2             2  MAP Dataset  ...              A  Agast Threshold= 60
# 3             3  MAP Dataset  ...              A  Agast Threshold= 60
# 4             4  MAP Dataset  ...              A  Agast Threshold= 60
# ..          ...          ...  ...            ...                   ...
# 114         114  MAP Dataset  ...              C   Agast Threshold= 60
# 115         115  MAP Dataset  ...              C   Agast Threshold= 60
# 116         116  MAP Dataset  ...              C   Agast Threshold= 60
# 117         117  MAP Dataset  ...              C   Agast Threshold= 60
# 118         118  MAP Dataset  ...              C   Agast Threshold= 60
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matchesfor AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matchesfor AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for AGAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for AGAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for AGAST+SIFT for different parameter combinations')

# %%
SURF=df1.loc[(df1['Detector/Descriptor'] == "SURF")]

# %%
SURF['Parameter'] = "hessianThreshold = 60"

# %%
SURF
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 476         476  MAP Dataset  ...              A  hessianThreshold = 60
# 477         477  MAP Dataset  ...              A  hessianThreshold = 60
# 478         478  MAP Dataset  ...              A  hessianThreshold = 60
# 479         479  MAP Dataset  ...              A  hessianThreshold = 60
# 480         480  MAP Dataset  ...              A  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 590         590  MAP Dataset  ...              A  hessianThreshold = 60
# 591         591  MAP Dataset  ...              A  hessianThreshold = 60
# 592         592  MAP Dataset  ...              A  hessianThreshold = 60
# 593         593  MAP Dataset  ...              A  hessianThreshold = 60
# 594         594  MAP Dataset  ...              A  hessianThreshold = 60
#
# [119 rows x 10 columns]

# %%
SURF1=df2.loc[(df2['Detector/Descriptor'] == "SURF")]

# %%
SURF1['Parameter'] = "hessianThreshold = 20"

# %%
SURF1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 476         476  MAP Dataset  ...              B  hessianThreshold = 20
# 477         477  MAP Dataset  ...              B  hessianThreshold = 20
# 478         478  MAP Dataset  ...              B  hessianThreshold = 20
# 479         479  MAP Dataset  ...              B  hessianThreshold = 20
# 480         480  MAP Dataset  ...              B  hessianThreshold = 20
# ..          ...          ...  ...            ...                    ...
# 590         590  MAP Dataset  ...              B  hessianThreshold = 20
# 591         591  MAP Dataset  ...              B  hessianThreshold = 20
# 592         592  MAP Dataset  ...              B  hessianThreshold = 20
# 593         593  MAP Dataset  ...              B  hessianThreshold = 20
# 594         594  MAP Dataset  ...              B  hessianThreshold = 20
#
# [119 rows x 10 columns]

# %%
SURF2=df3.loc[(df3['Detector/Descriptor'] == "SURF")]

# %%
SURF2['Parameter'] = "hessianThreshold = 60"

# %%
SURF2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 476         476  MAP Dataset  ...              C  hessianThreshold = 60
# 477         477  MAP Dataset  ...              C  hessianThreshold = 60
# 478         478  MAP Dataset  ...              C  hessianThreshold = 60
# 479         479  MAP Dataset  ...              C  hessianThreshold = 60
# 480         480  MAP Dataset  ...              C  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 590         590  MAP Dataset  ...              C  hessianThreshold = 60
# 591         591  MAP Dataset  ...              C  hessianThreshold = 60
# 592         592  MAP Dataset  ...              C  hessianThreshold = 60
# 593         593  MAP Dataset  ...              C  hessianThreshold = 60
# 594         594  MAP Dataset  ...              C  hessianThreshold = 60
#
# [119 rows x 10 columns]

# %%
ALL_SURF=pd.concat([SURF, SURF1, SURF2])

# %%
ALL_SURF
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName              Parameter
# 476         476  MAP Dataset  ...              A  hessianThreshold = 60
# 477         477  MAP Dataset  ...              A  hessianThreshold = 60
# 478         478  MAP Dataset  ...              A  hessianThreshold = 60
# 479         479  MAP Dataset  ...              A  hessianThreshold = 60
# 480         480  MAP Dataset  ...              A  hessianThreshold = 60
# ..          ...          ...  ...            ...                    ...
# 590         590  MAP Dataset  ...              C  hessianThreshold = 60
# 591         591  MAP Dataset  ...              C  hessianThreshold = 60
# 592         592  MAP Dataset  ...              C  hessianThreshold = 60
# 593         593  MAP Dataset  ...              C  hessianThreshold = 60
# 594         594  MAP Dataset  ...              C  hessianThreshold = 60
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SURF, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF for different parameter combinations')

# %%
FREAK=df1.loc[(df1['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 238         238  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 239         239  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 240         240  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              A  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 352         352  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 353         353  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 354         354  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 355         355  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              A  Threshold=60, Octaves=6
#
# [119 rows x 10 columns]

# %%
FREAK1=df2.loc[(df2['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK1['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 238         238  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 239         239  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 240         240  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              B  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 352         352  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 353         353  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 354         354  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 355         355  MAP Dataset  ...              B  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              B  Threshold=60, Octaves=6
#
# [119 rows x 10 columns]

# %%
FREAK2=df3.loc[(df3['Detector/Descriptor'] == "BRISK+FREAK")]

# %%
FREAK2['Parameter'] = "Threshold=60, Octaves=6"

# %%
FREAK2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 238         238  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 239         239  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 240         240  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              C  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 352         352  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 353         353  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 354         354  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 355         355  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              C  Threshold=60, Octaves=6
#
# [119 rows x 10 columns]

# %%
ALL_FREAK=pd.concat([FREAK, FREAK1, FREAK2])

# %%
ALL_FREAK
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName                Parameter
# 238         238  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 239         239  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 240         240  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 241         241  MAP Dataset  ...              A  Threshold=60, Octaves=6
# 242         242  MAP Dataset  ...              A  Threshold=60, Octaves=6
# ..          ...          ...  ...            ...                      ...
# 352         352  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 353         353  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 354         354  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 355         355  MAP Dataset  ...              C  Threshold=60, Octaves=6
# 356         356  MAP Dataset  ...              C  Threshold=60, Octaves=6
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for BRISK+FREAK for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FREAK, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for BRISK+FREAK for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for BRISK+FREAK for different parameter combinations')

# %%
SIFT=df1.loc[(df1['Detector/Descriptor'] == "SIFT")]

# %%
SIFT['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 120         120  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 121         121  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 122         122  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 123         123  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 233         233  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [119 rows x 10 columns]

# %%
SIFT1=df2.loc[(df2['Detector/Descriptor'] == "SIFT")]

# %%
SIFT1['Parameter'] = "nfeatures = 1000, contrastThreshold=0.02, edgeThreshold=4"

# %%
SIFT1
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 120         120  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 121         121  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 122         122  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 123         123  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 233         233  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 1000, contrastThreshold=0.02, edge...
#
# [119 rows x 10 columns]

# %%
SIFT2=df3.loc[(df3['Detector/Descriptor'] == "SIFT")]

# %%
SIFT2['Parameter'] = "nfeatures = 2000, contrastThreshold=0.02, edgeThreshold=6"

# %%
SIFT2
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 120         120  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 121         121  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 122         122  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 123         123  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 233         233  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [119 rows x 10 columns]

# %%
ALL_SIFT=pd.concat([SIFT, SIFT1, SIFT2])

# %%
ALL_SIFT
# Out:
#      Unnamed: 0  ...                                          Parameter
# 119         119  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 120         120  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 121         121  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 122         122  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 123         123  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# ..          ...  ...                                                ...
# 233         233  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 234         234  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 235         235  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 236         236  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
# 237         237  ...  nfeatures = 2000, contrastThreshold=0.02, edge...
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_SIFT, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SIFT for different parameter combinations')

# %%
FAST=df1.loc[(df1['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST['Parameter'] = "Threshold=60"

# %%
FAST
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 357         357  MAP Dataset  ...              A  Threshold=60
# 358         358  MAP Dataset  ...              A  Threshold=60
# 359         359  MAP Dataset  ...              A  Threshold=60
# 360         360  MAP Dataset  ...              A  Threshold=60
# 361         361  MAP Dataset  ...              A  Threshold=60
# ..          ...          ...  ...            ...           ...
# 471         471  MAP Dataset  ...              A  Threshold=60
# 472         472  MAP Dataset  ...              A  Threshold=60
# 473         473  MAP Dataset  ...              A  Threshold=60
# 474         474  MAP Dataset  ...              A  Threshold=60
# 475         475  MAP Dataset  ...              A  Threshold=60
#
# [119 rows x 10 columns]

# %%
FAST1=df2.loc[(df2['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST1['Parameter'] = "Threshold=40"

# %%
FAST1
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 357         357  MAP Dataset  ...              B  Threshold=40
# 358         358  MAP Dataset  ...              B  Threshold=40
# 359         359  MAP Dataset  ...              B  Threshold=40
# 360         360  MAP Dataset  ...              B  Threshold=40
# 361         361  MAP Dataset  ...              B  Threshold=40
# ..          ...          ...  ...            ...           ...
# 471         471  MAP Dataset  ...              B  Threshold=40
# 472         472  MAP Dataset  ...              B  Threshold=40
# 473         473  MAP Dataset  ...              B  Threshold=40
# 474         474  MAP Dataset  ...              B  Threshold=40
# 475         475  MAP Dataset  ...              B  Threshold=40
#
# [119 rows x 10 columns]

# %%
FAST2=df3.loc[(df3['Detector/Descriptor'] == "FAST+SIFT")]

# %%
FAST2['Parameter'] = "Threshold=60"

# %%
FAST2
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 357         357  MAP Dataset  ...              C  Threshold=60
# 358         358  MAP Dataset  ...              C  Threshold=60
# 359         359  MAP Dataset  ...              C  Threshold=60
# 360         360  MAP Dataset  ...              C  Threshold=60
# 361         361  MAP Dataset  ...              C  Threshold=60
# ..          ...          ...  ...            ...           ...
# 471         471  MAP Dataset  ...              C  Threshold=60
# 472         472  MAP Dataset  ...              C  Threshold=60
# 473         473  MAP Dataset  ...              C  Threshold=60
# 474         474  MAP Dataset  ...              C  Threshold=60
# 475         475  MAP Dataset  ...              C  Threshold=60
#
# [119 rows x 10 columns]

# %%
ALL_FAST=pd.concat([FAST, FAST1, FAST2])

# %%
ALL_FAST
# Out:
#      Unnamed: 0      Dataset  ...  ParameterName     Parameter
# 357         357  MAP Dataset  ...              A  Threshold=60
# 358         358  MAP Dataset  ...              A  Threshold=60
# 359         359  MAP Dataset  ...              A  Threshold=60
# 360         360  MAP Dataset  ...              A  Threshold=60
# 361         361  MAP Dataset  ...              A  Threshold=60
# ..          ...          ...  ...            ...           ...
# 471         471  MAP Dataset  ...              C  Threshold=60
# 472         472  MAP Dataset  ...              C  Threshold=60
# 473         473  MAP Dataset  ...              C  Threshold=60
# 474         474  MAP Dataset  ...              C  Threshold=60
# 475         475  MAP Dataset  ...              C  Threshold=60
#
# [357 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Recall Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Recall Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for FAST+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=ALL_FAST, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for FAST+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for FAST+SIFT for different parameter combinations')
