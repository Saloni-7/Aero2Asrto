# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Sutf+Sift_without image enhance(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('/content/Num_Kypoints_1_Small Village Dataset_Sutf+Sift_without image enhance(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/Num_Kypoints_1_Small Village DatasetSutf+Sift_without image enhance(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...            SURF+SIFT             A
# 1            1  Small Village Dataset  ...            SURF+SIFT             A
# 2            2  Small Village Dataset  ...            SURF+SIFT             A
# 3            3  Small Village Dataset  ...            SURF+SIFT             A
# 4            4  Small Village Dataset  ...            SURF+SIFT             A
# ..         ...                    ...  ...                  ...           ...
# 95          95  Small Village Dataset  ...            SURF+SIFT             A
# 96          96  Small Village Dataset  ...            SURF+SIFT             A
# 97          97  Small Village Dataset  ...            SURF+SIFT             A
# 98          98  Small Village Dataset  ...            SURF+SIFT             A
# 99          99  Small Village Dataset  ...            SURF+SIFT             A
#
# [100 rows x 5 columns]

# %%
df1['Parameter'] = "Surf:hessianThreshold =40"

# %%
df1
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 1            1  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 2            2  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 3            3  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 4            4  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# ..         ...                    ...  ...            ...                        ...
# 95          95  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 96          96  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 97          97  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 98          98  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# ...

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...            SURF+SIFT             B
# 1            1  Small Village Dataset  ...            SURF+SIFT             B
# 2            2  Small Village Dataset  ...            SURF+SIFT             B
# 3            3  Small Village Dataset  ...            SURF+SIFT             B
# 4            4  Small Village Dataset  ...            SURF+SIFT             B
# ..         ...                    ...  ...                  ...           ...
# 95          95  Small Village Dataset  ...            SURF+SIFT             B
# 96          96  Small Village Dataset  ...            SURF+SIFT             B
# 97          97  Small Village Dataset  ...            SURF+SIFT             B
# 98          98  Small Village Dataset  ...            SURF+SIFT             B
# 99          99  Small Village Dataset  ...            SURF+SIFT             B
#
# [100 rows x 5 columns]

# %%
df2['Parameter'] = "Surf:hessianThreshold =60"

# %%
df2
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 1            1  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 2            2  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 3            3  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 4            4  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# ..         ...                    ...  ...            ...                        ...
# 95          95  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 96          96  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 97          97  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# 98          98  Small Village Dataset  ...              B  Surf:hessianThreshold =60
# ...

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  Detector/Descriptor ParameterName
# 0            0  Small Village Dataset  ...            SURF+SIFT             C
# 1            1  Small Village Dataset  ...            SURF+SIFT             C
# 2            2  Small Village Dataset  ...            SURF+SIFT             C
# 3            3  Small Village Dataset  ...            SURF+SIFT             C
# 4            4  Small Village Dataset  ...            SURF+SIFT             C
# ..         ...                    ...  ...                  ...           ...
# 95          95  Small Village Dataset  ...            SURF+SIFT             C
# 96          96  Small Village Dataset  ...            SURF+SIFT             C
# 97          97  Small Village Dataset  ...            SURF+SIFT             C
# 98          98  Small Village Dataset  ...            SURF+SIFT             C
# 99          99  Small Village Dataset  ...            SURF+SIFT             C
#
# [100 rows x 5 columns]

# %%
df3['Parameter'] = "Surf:hessianThreshold =80"

# %%
df3
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 1            1  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 2            2  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 3            3  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 4            4  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# ..         ...                    ...  ...            ...                        ...
# 95          95  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 96          96  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 97          97  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 98          98  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# ...

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0                Dataset  ...  ParameterName                  Parameter
# 0            0  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 1            1  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 2            2  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 3            3  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# 4            4  Small Village Dataset  ...              A  Surf:hessianThreshold =40
# ..         ...                    ...  ...            ...                        ...
# 95          95  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 96          96  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 97          97  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# 98          98  Small Village Dataset  ...              C  Surf:hessianThreshold =80
# ...

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Keypoints", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Total Number of Keypoints b/w Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Total Number of Keypoints Detected for SURF+SIFT for different parameter combinations')
