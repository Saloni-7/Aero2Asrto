# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#d = {'Detector': ['Agast','agast','agast'], 'Number of Total Matches':[100,200,300],'Parameter':['Parameter1','Parameter2','Parameter3'],'ParameterName':['A','B','C'] }

# %%
df1=pd.read_csv('/content/All_metrics_1_MAP_Surf+sift_without image enhancement(0.35x).csv')

# %%
df1['ParameterName'] = "A"

# %%
df2=pd.read_csv('//content/All_metrics_1_MAP_surf+sift_without image enhancement(0.35x)_1.csv')

# %%
df2['ParameterName'] = "B"

# %%
df3=pd.read_csv('/content/All_metrics_1_MAP_surf+sift_without image enhancement(0.35x)_2.csv')

# %%
df3['ParameterName'] = "C"

# %%
df1
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.142740             A
# 1            1  MAP Dataset  ...  0.123485             A
# 2            2  MAP Dataset  ...  0.130526             A
# 3            3  MAP Dataset  ...  0.162705             A
# 4            4  MAP Dataset  ...  0.177163             A
# ..         ...          ...  ...       ...           ...
# 94          94  MAP Dataset  ...  0.132157             A
# 95          95  MAP Dataset  ...  0.121449             A
# 96          96  MAP Dataset  ...  0.126618             A
# 97          97  MAP Dataset  ...  0.124118             A
# 98          98  MAP Dataset  ...  0.113653             A
#
# [99 rows x 9 columns]

# %%
df1['Parameter'] = "Surf:hessianThreshold =80, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df1
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 94          94  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 95          95  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
#
# [99 rows x 10 columns]

# %%
df2
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.137751             B
# 1            1  MAP Dataset  ...  0.129757             B
# 2            2  MAP Dataset  ...  0.128050             B
# 3            3  MAP Dataset  ...  0.128171             B
# 4            4  MAP Dataset  ...  0.165281             B
# ..         ...          ...  ...       ...           ...
# 94          94  MAP Dataset  ...  0.121410             B
# 95          95  MAP Dataset  ...  0.128000             B
# 96          96  MAP Dataset  ...  0.124189             B
# 97          97  MAP Dataset  ...  0.125321             B
# 98          98  MAP Dataset  ...  0.111302             B
#
# [99 rows x 9 columns]

# %%
df2['Parameter'] = "Surf:hessianThreshold =60, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df2
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 94          94  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 95          95  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =60, nOctaves = 4, nOcta...
#
# [99 rows x 10 columns]

# %%
df3
# Out:
#     Unnamed: 0      Dataset  ...   F-Score ParameterName
# 0            0  MAP Dataset  ...  0.130575             C
# 1            1  MAP Dataset  ...  0.119868             C
# 2            2  MAP Dataset  ...  0.120372             C
# 3            3  MAP Dataset  ...  0.145856             C
# 4            4  MAP Dataset  ...  0.150827             C
# ..         ...          ...  ...       ...           ...
# 94          94  MAP Dataset  ...  0.123896             C
# 95          95  MAP Dataset  ...  0.129591             C
# 96          96  MAP Dataset  ...  0.122164             C
# 97          97  MAP Dataset  ...  0.099260             C
# 98          98  MAP Dataset  ...  0.100523             C
#
# [99 rows x 9 columns]

# %%
df3['Parameter'] = "Surf:hessianThreshold =40, nOctaves = 4, nOctaveLayers = 3; Sift:nfeatures = 1000, nOctaveLayers = 3, contrastThreshold = 0.04, edgeThreshold = 10 "

# %%
df3
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 94          94  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 95          95  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
#
# [99 rows x 10 columns]

# %%
df=pd.concat([df1,df2,df3])

# %%
df
# Out:
#     Unnamed: 0  ...                                          Parameter
# 0            0  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 1            1  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 2            2  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 3            3  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# 4            4  ...  Surf:hessianThreshold =80, nOctaves = 4, nOcta...
# ..         ...  ...                                                ...
# 94          94  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 95          95  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 96          96  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 97          97  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
# 98          98  ...  Surf:hessianThreshold =40, nOctaves = 4, nOcta...
#
# [297 rows x 10 columns]

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Recall Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Recall Rate for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("recall Rate for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'recall Rate for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Good Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Good Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Good Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Good Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="Number of Total Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "Number of Total Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("Number of Total Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'Number of Total Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="1 - Precision Rate of Matches", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "1 - Precision Rate of Matches for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, '1 - Precision Rate of Matches for SURF+SIFT for different parameter combinations')

# %%
 import seaborn as sns
sns.set_theme(style='whitegrid')


g = sns.catplot(
    data=df, kind="bar",
    x="ParameterName", y="F-Score", hue="Parameter" ,
    ci="sd", palette="Spectral", alpha=.9, height=8, aspect=0.9
)
g.despine(left=True)
g.set_axis_labels("Parameter Combinations ", "F-Score for Consecutive/Overlapping Images")
g.legend.set_title("Parameter Combinations")
g.fig.suptitle("F-Score for SURF+SIFT for different parameter combinations")
# Out:
# Text(0.5, 0.98, 'F-Score for SURF+SIFT for different parameter combinations')
